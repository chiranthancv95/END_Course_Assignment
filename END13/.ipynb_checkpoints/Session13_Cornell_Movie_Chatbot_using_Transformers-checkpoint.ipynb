# %% [markdown]
# # Chatbot Using Transformers

# %% [markdown]
# In this notebook, we will train a simple chatbot using movie
# scripts from the [Cornell Movie-Dialogs
# Corpus](https://www.cs.cornell.edu/~cristian/Cornell_Movie-Dialogs_Corpus.html).
#
# Conversational models are a hot topic in artificial intelligence
# research. Chatbots can be found in a variety of settings, including
# customer service applications and online helpdesks. These bots are often
# powered by retrieval-based models, which output predefined responses to
# questions of certain forms. In a highly restricted domain like a
# company’s IT helpdesk, these models may be sufficient, however, they are
# not robust enough for more general use-cases. Teaching a machine to
# carry out a meaningful conversation with a human in multiple domains is
# a research question that is far from solved. Recently, the deep learning
# boom has allowed for powerful generative models like Google’s [Neural
# Conversational Model](https://arxiv.org/abs/1506.05869), which marks
# a large step towards multi-domain generative conversational models. In
# this notebook, we will implement this kind of model in PyTorch.
#
#
#
# -  Handle loading and preprocessing of [Cornell Movie-Dialogs Corpus](https://www.cs.cornell.edu/~cristian/Cornell_Movie-Dialogs_Corpus.html) dataset
#
# - Refer the code from this [Pytorch tutorial](https://pytorch.org/tutorials/beginner/chatbot_tutorial.html) for integrating the dataset.
# - GRU based encoder-decoder architecture mentioned in the PyTorch code. However, we will be reimplementing above code using transformers to make it into a chatbot
# - Achieve a loss of less than 2.4 in any epoch.
# - the same loss function/methodology as used in the PyTorch sample code will be used, else your evaluation would not be comparable and 2.4 doesn't make sense

# %% [markdown]
# Preparations
# ------------
#
# To start, Download the data ZIP file
# [here](https://www.cs.cornell.edu/~cristian/Cornell_Movie-Dialogs_Corpus.html)
# and upload to google drive.
#
# After that, let’s import some necessities.

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
from __future__ import unicode_literals

import torch
from torch.jit import script, trace
import torch.nn as nn
from torch import optim
import torch.nn.functional as F
import csv
import random
import re
import os
import unicodedata
import codecs
from io import open
import itertools
import math
import time

import numpy as np

import spacy
spacy_en = spacy.load('en')

import random
SEED = 1234

random.seed(SEED)
torch.cuda.manual_seed(SEED)
torch.backends.cudnn.deterministic = True
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-9bb4af878297> in <module>
#      22 import numpy as np
#      23
# ---> 24 import spacy
#      25 spacy_en = spacy.load('en')
#      26
#
# ModuleNotFoundError: No module named 'spacy'

# %%
# !wget http://www.cs.cornell.edu/~cristian/data/cornell_movie_dialogs_corpus.zip
# Out:
# --2021-02-22 23:57:14--  http://www.cs.cornell.edu/~cristian/data/cornell_movie_dialogs_corpus.zip
# Resolving www.cs.cornell.edu (www.cs.cornell.edu)... 132.236.207.36
# Connecting to www.cs.cornell.edu (www.cs.cornell.edu)|132.236.207.36|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9916637 (9.5M) [application/zip]
# Saving to: ‘cornell_movie_dialogs_corpus.zip’
#
# gs_corpus.zip         1%[                    ] 155.76K  --.-KB/s    eta 67m 9s

# %%
# !unzip '/content/cornell_movie_dialogs_corpus.zip'
# Out:
# Archive:  /content/cornell_movie_dialogs_corpus.zip
# replace cornell movie-dialogs corpus/.DS_Store? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: cornell movie-dialogs corpus/.DS_Store
#   inflating: __MACOSX/cornell movie-dialogs corpus/._.DS_Store
#   inflating: cornell movie-dialogs corpus/chameleons.pdf
#   inflating: __MACOSX/cornell movie-dialogs corpus/._chameleons.pdf
#   inflating: cornell movie-dialogs corpus/movie_characters_metadata.txt
#   inflating: cornell movie-dialogs corpus/movie_conversations.txt
#   inflating: cornell movie-dialogs corpus/movie_lines.txt
#   inflating: cornell movie-dialogs corpus/movie_titles_metadata.txt
#   inflating: cornell movie-dialogs corpus/raw_script_urls.txt
#   inflating: cornell movie-dialogs corpus/README.txt
#   inflating: __MACOSX/cornell movie-dialogs corpus/._README.txt

# %% [markdown]
# Load & Preprocess Data
# ----------------------
#
# The next step is to reformat our data file and load the data into
# structures that we can work with.
#
# The [Cornell Movie-Dialogs
# Corpus](https://www.cs.cornell.edu/~cristian/Cornell_Movie-Dialogs_Corpus.html)
# is a rich dataset of movie character dialog:
#
# -  220,579 conversational exchanges between 10,292 pairs of movie
#    characters
# -  9,035 characters from 617 movies
# -  304,713 total utterances
#
# This dataset is large and diverse, and there is a great variation of
# language formality, time periods, sentiment, etc. Our hope is that this
# diversity makes our model robust to many forms of inputs and queries.
#
# First, we’ll take a look at some lines of our datafile to see the
# original format.

# %%
corpus_name = "cornell movie-dialogs corpus"
corpus = os.path.join("/content/", corpus_name)

def printLines(file, n=10):
    with open(file, 'rb') as datafile:
        lines = datafile.readlines()
    for line in lines[:n]:
        print(line)

printLines(os.path.join(corpus, "movie_lines.txt"))
#printLines('/content/cornell movie-dialogs corpus/movie_lines.txt')
# Out:
# b'L1045 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ They do not!\n'
# b'L1044 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ They do to!\n'
# b'L985 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ I hope so.\n'
# b'L984 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ She okay?\n'
# b"L925 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Let's go.\n"
# b'L924 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Wow\n'
# b"L872 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Okay -- you're gonna need to learn how to lie.\n"
# b'L871 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ No\n'
# b'L870 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ I\'m kidding.  You know how sometimes you just become this "persona"?  And you don\'t know how to quit?\n'
# b'L869 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Like my fear of wearing pastels?\n'

# %%
# !ls '/content/cornell movie-dialogs corpus'
# Out:
# chameleons.pdf		       movie_conversations.txt	  raw_script_urls.txt
# formatted_movie_lines.txt      movie_lines.txt		  README.txt
# movie_characters_metadata.txt  movie_titles_metadata.txt

# %%
# !head -10 "/content/cornell movie-dialogs corpus/movie_conversations.txt"
# Out:
# u0 +++$+++ u2 +++$+++ m0 +++$+++ ['L194', 'L195', 'L196', 'L197']
# u0 +++$+++ u2 +++$+++ m0 +++$+++ ['L198', 'L199']
# u0 +++$+++ u2 +++$+++ m0 +++$+++ ['L200', 'L201', 'L202', 'L203']
# u0 +++$+++ u2 +++$+++ m0 +++$+++ ['L204', 'L205', 'L206']
# u0 +++$+++ u2 +++$+++ m0 +++$+++ ['L207', 'L208']
# u0 +++$+++ u2 +++$+++ m0 +++$+++ ['L271', 'L272', 'L273', 'L274', 'L275']
# u0 +++$+++ u2 +++$+++ m0 +++$+++ ['L276', 'L277']
# u0 +++$+++ u2 +++$+++ m0 +++$+++ ['L280', 'L281']
# u0 +++$+++ u2 +++$+++ m0 +++$+++ ['L363', 'L364']
# u0 +++$+++ u2 +++$+++ m0 +++$+++ ['L365', 'L366']

# %% [markdown]
# ## Create formatted data file
#
# For convenience, we'll create a nicely formatted data file in which each line
# contains a tab-separated *query sentence* and a *response sentence* pair.
#
# The following functions facilitate the parsing of the raw
# *movie_lines.txt* data file.
#
# -  ``loadLines`` splits each line of the file into a dictionary of
#    fields (lineID, characterID, movieID, character, text)
# -  ``loadConversations`` groups fields of lines from ``loadLines`` into
#    conversations based on *movie_conversations.txt*
# -  ``extractSentencePairs`` extracts pairs of sentences from
#    conversations

# %%
# Splits each line of the file into a dictionary of fields
def loadLines(fileName, fields):
    lines = {}
    with open(fileName, 'r', encoding='iso-8859-1') as f:
        for line in f:
            values = line.split(" +++$+++ ")
            # Extract fields
            lineObj = {}
            for i, field in enumerate(fields):
                lineObj[field] = values[i]
            lines[lineObj['lineID']] = lineObj
    return lines


# Groups fields of lines from `loadLines` into conversations based on *movie_conversations.txt*
def loadConversations(fileName, lines, fields):
    conversations = []
    with open(fileName, 'r', encoding='iso-8859-1') as f:
        for line in f:
            values = line.split(" +++$+++ ")
            # Extract fields
            convObj = {}
            for i, field in enumerate(fields):
                convObj[field] = values[i]
            # Convert string to list (convObj["utteranceIDs"] == "['L598485', 'L598486', ...]")
            utterance_id_pattern = re.compile('L[0-9]+')
            lineIds = utterance_id_pattern.findall(convObj["utteranceIDs"])
            # Reassemble lines
            convObj["lines"] = []
            for lineId in lineIds:
                convObj["lines"].append(lines[lineId])
            conversations.append(convObj)
    return conversations


# Extracts pairs of sentences from conversations
def extractSentencePairs(conversations):
    qa_pairs = []
    for conversation in conversations:
        # Iterate over all the lines of the conversation
        for i in range(len(conversation["lines"]) - 1):  # We ignore the last line (no answer for it)
            inputLine = conversation["lines"][i]["text"].strip()
            targetLine = conversation["lines"][i+1]["text"].strip()
            # Filter wrong samples (if one of the lists is empty)
            if inputLine and targetLine:
                qa_pairs.append([inputLine, targetLine])
    return qa_pairs

# %% [markdown]
# Now we’ll call these functions and create the file. We’ll call it
# *formatted_movie_lines.txt*.

# %%
# Define path to new file
datafile = os.path.join(corpus, "formatted_movie_lines.txt")

delimiter = '\t'
# Unescape the delimiter
delimiter = str(codecs.decode(delimiter, "unicode_escape"))

# Initialize lines dict, conversations list, and field ids
lines = {}
conversations = []
MOVIE_LINES_FIELDS = ["lineID", "characterID", "movieID", "character", "text"]
MOVIE_CONVERSATIONS_FIELDS = ["character1ID", "character2ID", "movieID", "utteranceIDs"]

# Load lines and process conversations
print("\nProcessing corpus...")
lines = loadLines(os.path.join(corpus, "movie_lines.txt"), MOVIE_LINES_FIELDS)

# Ouput of the above is a dictionary with details of each lineid captured from movie_lines.txt file  in below format:
# lines['L1045']
# {'character': 'BIANCA',
#  'characterID': 'u0',
#  'lineID': 'L1045',
#  'movieID': 'm0',
#  'text': 'They do not!\n'}

print("\nLoading conversations...")
conversations = loadConversations(os.path.join(corpus, "movie_conversations.txt"),
                                  lines, MOVIE_CONVERSATIONS_FIELDS)

"""Conversations is a list of lists, where each sublist will have contain the details of the utterances ['L194', 'L195', 'L196', 'L197'] 
for conversation in conversations:
  print(conversation["lines"])
  break

[{'lineID': 'L194', 'characterID': 'u0', 'movieID': 'm0', 'character': 'BIANCA', 'text': 'Can we make this quick?  Roxanne Korrine and Andrew Barrett are having an incredibly horrendous public break- up on the quad.  Again.\n'}, 
{'lineID': 'L195', 'characterID': 'u2', 'movieID': 'm0', 'character': 'CAMERON', 'text': "Well, I thought we'd start with pronunciation, if that's okay with you.\n"}, 
{'lineID': 'L196', 'characterID': 'u0', 'movieID': 'm0', 'character': 'BIANCA', 'text': 'Not the hacking and gagging and spitting part.  Please.\n'}, 
{'lineID': 'L197', 'characterID': 'u2', 'movieID': 'm0', 'character': 'CAMERON', 'text': "Okay... then how 'bout we try out some French cuisine.  Saturday?  Night?\n"}]"""

# Write new csv file
print("\nWriting newly formatted file...")
with open(datafile, 'w', encoding='utf-8') as outputfile:
    writer = csv.writer(outputfile, delimiter=delimiter, lineterminator='\n')
    for pair in extractSentencePairs(conversations):
        writer.writerow(pair)

# Print a sample of lines
print("\nSample lines from file:")
printLines(datafile)
# Out:
# Processing corpus...
#
# Loading conversations...
#
# Writing newly formatted file...
#
# Sample lines from file:
# b"Can we make this quick?  Roxanne Korrine and Andrew Barrett are having an incredibly horrendous public break- up on the quad.  Again.\tWell, I thought we'd start with pronunciation, if that's okay with you.\n"
# b"Well, I thought we'd start with pronunciation, if that's okay with you.\tNot the hacking and gagging and spitting part.  Please.\n"
# b"Not the hacking and gagging and spitting part.  Please.\tOkay... then how 'bout we try out some French cuisine.  Saturday?  Night?\n"
# b"You're asking me out.  That's so cute. What's your name again?\tForget it.\n"
# b"No, no, it's my fault -- we didn't have a proper introduction ---\tCameron.\n"
# b"Cameron.\tThe thing is, Cameron -- I'm at the mercy of a particularly hideous breed of loser.  My sister.  I can't date until she does.\n"
# b"The thing is, Cameron -- I'm at the mercy of a particularly hideous breed of loser.  My sister.  I can't date until she does.\tSeems like she could get a date easy enough...\n"
# b'Why?\tUnsolved mystery.  She used to be really popular when she started high school, then it was just like she got sick of it or something.\n'
# b"Unsolved mystery.  She used to be really popular when she started high school, then it was just like she got sick of it or something.\tThat's a shame.\n"
# b'Gosh, if only we could find Kat a boyfriend...\tLet me see what I can do.\n'

# %%
lines['L1045']
# Out:
# {'character': 'BIANCA',
#  'characterID': 'u0',
#  'lineID': 'L1045',
#  'movieID': 'm0',
#  'text': 'They do not!\n'}

# %%
for conversation in conversations:
  print(conversation["lines"])
  break
# Out:
# [{'lineID': 'L194', 'characterID': 'u0', 'movieID': 'm0', 'character': 'BIANCA', 'text': 'Can we make this quick?  Roxanne Korrine and Andrew Barrett are having an incredibly horrendous public break- up on the quad.  Again.\n'}, {'lineID': 'L195', 'characterID': 'u2', 'movieID': 'm0', 'character': 'CAMERON', 'text': "Well, I thought we'd start with pronunciation, if that's okay with you.\n"}, {'lineID': 'L196', 'characterID': 'u0', 'movieID': 'm0', 'character': 'BIANCA', 'text': 'Not the hacking and gagging and spitting part.  Please.\n'}, {'lineID': 'L197', 'characterID': 'u2', 'movieID': 'm0', 'character': 'CAMERON', 'text': "Okay... then how 'bout we try out some French cuisine.  Saturday?  Night?\n"}]

# %%
qa_pairs = extractSentencePairs(conversations)
for pair in qa_pairs:
  print("one qa pair from the extract sentence pairs")
  print(pair)

  print("\nIndividual Quesntion and Response")
  print("Question:",pair[0])
  print("Response:", pair[1])

  break
# Out:
# one qa pair from the extract sentence pairs
# ['Can we make this quick?  Roxanne Korrine and Andrew Barrett are having an incredibly horrendous public break- up on the quad.  Again.', "Well, I thought we'd start with pronunciation, if that's okay with you."]
#
# Individual Quesntion and Response
# Question: Can we make this quick?  Roxanne Korrine and Andrew Barrett are having an incredibly horrendous public break- up on the quad.  Again.
# Response: Well, I thought we'd start with pronunciation, if that's okay with you.

# %%
# !head -10 '/content/cornell movie-dialogs corpus/formatted_movie_lines.txt'
# Out:
# Can we make this quick?  Roxanne Korrine and Andrew Barrett are having an incredibly horrendous public break- up on the quad.  Again.	Well, I thought we'd start with pronunciation, if that's okay with you.
# Well, I thought we'd start with pronunciation, if that's okay with you.	Not the hacking and gagging and spitting part.  Please.
# Not the hacking and gagging and spitting part.  Please.	Okay... then how 'bout we try out some French cuisine.  Saturday?  Night?
# You're asking me out.  That's so cute. What's your name again?	Forget it.
# No, no, it's my fault -- we didn't have a proper introduction ---	Cameron.
# Cameron.	The thing is, Cameron -- I'm at the mercy of a particularly hideous breed of loser.  My sister.  I can't date until she does.
# The thing is, Cameron -- I'm at the mercy of a particularly hideous breed of loser.  My sister.  I can't date until she does.	Seems like she could get a date easy enough...
# Why?	Unsolved mystery.  She used to be really popular when she started high school, then it was just like she got sick of it or something.
# Unsolved mystery.  She used to be really popular when she started high school, then it was just like she got sick of it or something.	That's a shame.
# Gosh, if only we could find Kat a boyfriend...	Let me see what I can do.

# %% [markdown]
# ## Load and trim data
#
# Our next order of business is to create a vocabulary and load query/response sentence pairs into memory.
# Note that we are dealing with sequences of words, which do not have an implicit mapping to a discrete numerical space.

# %%
# # Default word tokens
# PAD_token = 0  # Used for padding short sentences
# SOS_token = 1  # Start-of-sentence token
# EOS_token = 2  # End-of-sentence token

# class Voc:
#     def __init__(self, name):
#         self.name = name
#         self.trimmed = False
#         self.word2index = {}
#         self.word2count = {}
#         self.index2word = {PAD_token: "<pad>", SOS_token: "SOS", EOS_token: "EOS"}
#         self.num_words = 3  # Count SOS, EOS, PAD

#     def addSentence(self, sentence):
#         for word in sentence.split(' '):
#             self.addWord(word)

#     def addWord(self, word):
#         if word not in self.word2index:
#             self.word2index[word] = self.num_words
#             self.word2count[word] = 1
#             self.index2word[self.num_words] = word
#             self.num_words += 1
#         else:
#             self.word2count[word] += 1

#     # Remove words below a certain count threshold
#     def trim(self, min_count):
#         if self.trimmed:
#             return
#         self.trimmed = True

#         keep_words = []

#         for k, v in self.word2count.items():
#             if v >= min_count:
#                 keep_words.append(k)

#         print('keep_words {} / {} = {:.4f}'.format(
#             len(keep_words), len(self.word2index), len(keep_words) / len(self.word2index)
#         ))

#         # Reinitialize dictionaries
#         self.word2index = {}
#         self.word2count = {}
#         self.index2word = {PAD_token: "<pad>", SOS_token: "SOS", EOS_token: "EOS"}
#         self.num_words = 3 # Count default tokens

#         for word in keep_words:
#             self.addWord(word)

# %% [markdown]
# First, we must convert the Unicode strings to ASCII using unicodeToAscii. Next, we should convert all letters to lowercase and trim all non-letter characters except for basic punctuation (normalizeString). Finally, to aid in training convergence, we will filter out sentences with length greater than the MAX_LENGTH threshold (filterPairs).

# %%
MAX_LENGTH = 10  # Maximum sentence length to consider

# Turn a Unicode string to plain ASCII, thanks to
# https://stackoverflow.com/a/518232/2809427
def unicodeToAscii(s):
    return ''.join(
        c for c in unicodedata.normalize('NFD', s)
        if unicodedata.category(c) != 'Mn'
    )

# Lowercase, trim, and remove non-letter characters
def normalizeString(s):
    s = unicodeToAscii(s.lower().strip())
    s = re.sub(r"([.!?])", r" \1", s)
    s = re.sub(r"[^a-zA-Z.!?]+", r" ", s)
    s = re.sub(r"\s+", r" ", s).strip()
    return s

# Read query/response pairs and return a voc object
def readVocs(datafile, corpus_name):
    print("Reading lines...")
    # Read the file and split into lines
    lines = open(datafile, encoding='utf-8').\
        read().strip().split('\n')
    # Split every line into pairs and normalize
    pairs = [[normalizeString(s) for s in l.split('\t')] for l in lines]
    return  pairs

# Returns True iff both sentences in a pair 'p' are under the MAX_LENGTH threshold
def filterPair(p):
    # Input sequences need to preserve the last word for EOS token
    return len(p[0].split(' ')) < MAX_LENGTH and len(p[1].split(' ')) < MAX_LENGTH

# Filter pairs using filterPair condition
def filterPairs(pairs):
    return [pair for pair in pairs if filterPair(pair)]

# Using the functions defined above, return a populated voc object and pairs list
def loadPrepareData(corpus, corpus_name, datafile, save_dir):
    print("Start preparing training data ...")
    pairs = readVocs(datafile, corpus_name)
    print("Read {!s} sentence pairs".format(len(pairs)))
    pairs = filterPairs(pairs)
    print("Trimmed to {!s} sentence pairs".format(len(pairs)))
    return  pairs


# Load/Assemble voc and pairs
save_dir = os.path.join("data", "save")
pairs = loadPrepareData(corpus, corpus_name, datafile, save_dir)
# Print some pairs to validate
print("\npairs:")
for pair in pairs[:10]:
    print(pair)
# Out:
# Start preparing training data ...
# Reading lines...
# Read 221282 sentence pairs
# Trimmed to 64271 sentence pairs
#
# pairs:
# ['there .', 'where ?']
# ['you have my word . as a gentleman', 'you re sweet .']
# ['hi .', 'looks like things worked out tonight huh ?']
# ['you know chastity ?', 'i believe we share an art instructor']
# ['have fun tonight ?', 'tons']
# ['well no . . .', 'then that s all you had to say .']
# ['then that s all you had to say .', 'but']
# ['but', 'you always been this selfish ?']
# ['do you listen to this crap ?', 'what crap ?']
# ['what good stuff ?', 'the real you .']

# %%
# import os, pickle
# with open('w2i_tokenizer.pkl', 'wb') as w2i_tokens: 
#     pickle.dump(voc.word2index, w2i_tokens)

# with open('i2w_tokenizer.pkl', 'wb') as i2w_tokens: 
#     pickle.dump(voc.index2word, i2w_tokens)

# %%
len(pairs)
# Out:
# 64271

# %%
def tokenize_en(text):
    """
    Tokenizes English text from a string into a list of strings
    """
    return [tok.text for tok in spacy_en.tokenizer(text)]

# %%
import torch, torchtext
from torchtext import data
from torchtext.data import Field, BucketIterator

sentence=Field(tokenize = tokenize_en, 
            init_token = '<sos>', 
            eos_token = '<eos>', 
            lower = True, 
            batch_first = True)

# %%
fields = [('input_sentence', sentence),('output_sentence',sentence)]

# %%
chatbot_pairs = [data.Example.fromlist([p[0],p[1]], fields) for p in pairs] 
chatbot_pairs_dataset = data.Dataset(chatbot_pairs, fields)

# %%
len(chatbot_pairs_dataset)
# Out:
# 64271

# %%
train_data, valid_data = chatbot_pairs_dataset.split(split_ratio=[0.90,0.10])

# %%
vars(train_data.examples[100])
# Out:
# {'input_sentence': ['can', 'i', 'make', 'sandwiches', '.', '.', '.', '?'],
#  'output_sentence': ['yes',
#   'you',
#   'can',
#   'make',
#   'sandwiches',
#   '.',
#   '.',
#   '.',
#   '.']}

# %%
vars(valid_data.examples[100])
# Out:
# {'input_sentence': ['what', '?'],
#  'output_sentence': ['fight', '.', 'you', 'know', '.']}

# %%
sentence.build_vocab(chatbot_pairs_dataset, min_freq = 3)

# %%
len(sentence.vocab)
# Out:
# 7823

# %%
print(f"Unique tokens in  vocabulary: {len(sentence.vocab)}")
# Out:
# Unique tokens in  vocabulary: 7823

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')


BATCH_SIZE = 64

train_iterator, valid_iterator = BucketIterator.splits(
    (train_data, valid_data), 
    batch_size = BATCH_SIZE,
    sort_key = lambda x: len(x.input_sentence), 
    device = device)

# %%
class Seq2Seq(nn.Module):
    def __init__(self, 
                 encoder, 
                 decoder, 
                 src_pad_idx, 
                 trg_pad_idx, 
                 device):
        super().__init__()
        
        self.encoder = encoder
        self.decoder = decoder
        self.src_pad_idx = src_pad_idx
        self.trg_pad_idx = trg_pad_idx
        self.device = device
        
    def make_src_mask(self, src):
        
        #src = [batch size, src len]
        
        src_mask = (src != self.src_pad_idx).unsqueeze(1).unsqueeze(2)

        #src_mask = [batch size, 1, 1, src len]

        return src_mask
    
    def make_trg_mask(self, trg):
        
        #trg = [batch size, trg len]
        
        trg_pad_mask = (trg != self.trg_pad_idx).unsqueeze(1).unsqueeze(2)
        
        #trg_pad_mask = [batch size, 1, 1, trg len]
        
        trg_len = trg.shape[1]
        
        trg_sub_mask = torch.tril(torch.ones((trg_len, trg_len), device = self.device)).bool()
        
        #trg_sub_mask = [trg len, trg len]
            
        trg_mask = trg_pad_mask & trg_sub_mask
        
        #trg_mask = [batch size, 1, trg len, trg len]
        
        return trg_mask

    def forward(self, src, trg):
        
        #src = [batch size, src len]
        #trg = [batch size, trg len]
                
        src_mask = self.make_src_mask(src)
        trg_mask = self.make_trg_mask(trg)
        
        #src_mask = [batch size, 1, 1, src len]
        #trg_mask = [batch size, 1, trg len, trg len]


        enc_src = self.encoder(src, src_mask)
        
        #enc_src = [batch size, src len, hid dim]
                
        output, attention = self.decoder(trg, enc_src, trg_mask, src_mask)
        
        #output = [batch size, trg len, output dim]
        #attention = [batch size, n heads, trg len, src len]        
        return output, attention

# %%
class Encoder(nn.Module):
    def __init__(self, 
                 input_dim, 
                 hid_dim, 
                 n_layers, 
                 n_heads, 
                 pf_dim,
                 dropout, 
                 device,
                 max_length = 100):
        super().__init__()

        self.device = device
        
        self.tok_embedding = nn.Embedding(input_dim, hid_dim)
        self.pos_embedding = nn.Embedding(max_length, hid_dim)
        
        self.layers = nn.ModuleList([EncoderLayer(hid_dim, 
                                                  n_heads, 
                                                  pf_dim,
                                                  dropout, 
                                                  device) 
                                     for _ in range(n_layers)])
        
        self.dropout = nn.Dropout(dropout)
        
        self.scale = torch.sqrt(torch.FloatTensor([hid_dim])).to(device)
        
    def forward(self, src, src_mask):
        
        #src = [batch size, src len]
        #src_mask = [batch size, 1, 1, src len]
        
        batch_size = src.shape[0]
        src_len = src.shape[1]
        
        pos = torch.arange(0, src_len).unsqueeze(0).repeat(batch_size, 1).to(self.device)
        
        #pos = [batch size, src len]

        src = self.dropout((self.tok_embedding(src) * self.scale) + self.pos_embedding(pos))

        
        #src = [batch size, src len, hid dim]
        
        for layer in self.layers:
            src = layer(src, src_mask)
            
        #src = [batch size, src len, hid dim]
 
            
        return src

# %%
class EncoderLayer(nn.Module):
    def __init__(self, 
                 hid_dim, 
                 n_heads, 
                 pf_dim,  
                 dropout, 
                 device):
        super().__init__()
        
        self.self_attn_layer_norm = nn.LayerNorm(hid_dim)
        self.ff_layer_norm = nn.LayerNorm(hid_dim)
        self.self_attention = MultiHeadAttentionLayer(hid_dim, n_heads, dropout, device)
        self.positionwise_feedforward = PositionwiseFeedforwardLayer(hid_dim, 
                                                                     pf_dim, 
                                                                     dropout)
        self.dropout = nn.Dropout(dropout)
        
    def forward(self, src, src_mask):
        
        #src = [batch size, src len, hid dim]
        #src_mask = [batch size, 1, 1, src len] 
                
        #self attention
        _src, _ = self.self_attention(src, src, src, src_mask)
        
        #dropout, residual connection and layer norm
        src = self.self_attn_layer_norm(src + self.dropout(_src))
        
        #src = [batch size, src len, hid dim]
        
        #positionwise feedforward
        _src = self.positionwise_feedforward(src)
        
        #dropout, residual and layer norm
        src = self.ff_layer_norm(src + self.dropout(_src))
        
        #src = [batch size, src len, hid dim]
        
        return src

# %%
class MultiHeadAttentionLayer(nn.Module):
    def __init__(self, hid_dim, n_heads, dropout, device):
        super().__init__()
        
        assert hid_dim % n_heads == 0
        
        self.hid_dim = hid_dim
        self.n_heads = n_heads
        self.head_dim = hid_dim // n_heads
        
        self.fc_q = nn.Linear(hid_dim, hid_dim)
        self.fc_k = nn.Linear(hid_dim, hid_dim)
        self.fc_v = nn.Linear(hid_dim, hid_dim)
        
        self.fc_o = nn.Linear(hid_dim, hid_dim)
        
        self.dropout = nn.Dropout(dropout)
        
        self.scale = torch.sqrt(torch.FloatTensor([self.head_dim])).to(device)
        
    def forward(self, query, key, value, mask = None):
        
        batch_size = query.shape[0]
        
        #query = [batch size, query len, hid dim]
        #key = [batch size, key len, hid dim]
        #value = [batch size, value len, hid dim]
                
        Q = self.fc_q(query)
        K = self.fc_k(key)
        V = self.fc_v(value)
        
        #Q = [batch size, query len, hid dim]
        #K = [batch size, key len, hid dim]
        #V = [batch size, value len, hid dim]
                
        Q = Q.view(batch_size, -1, self.n_heads, self.head_dim).permute(0, 2, 1, 3)
        K = K.view(batch_size, -1, self.n_heads, self.head_dim).permute(0, 2, 1, 3)
        V = V.view(batch_size, -1, self.n_heads, self.head_dim).permute(0, 2, 1, 3)
        
        #Q = [batch size, n heads, query len, head dim]
        #K = [batch size, n heads, key len, head dim]
        #V = [batch size, n heads, value len, head dim]
                
        energy = torch.matmul(Q, K.permute(0, 1, 3, 2)) / self.scale
        
        #energy = [batch size, n heads, query len, key len]
        
        if mask is not None:
            energy = energy.masked_fill(mask == 0, -1e10)
        
        attention = torch.softmax(energy, dim = -1)
                
        #attention = [batch size, n heads, query len, key len]
                
        x = torch.matmul(self.dropout(attention), V)
        
        #x = [batch size, n heads, query len, head dim]
        
        x = x.permute(0, 2, 1, 3).contiguous()
        
        #x = [batch size, query len, n heads, head dim]
        
        x = x.view(batch_size, -1, self.hid_dim)
        
        #x = [batch size, query len, hid dim]
        
        x = self.fc_o(x)
        
        #x = [batch size, query len, hid dim]
        
        return x, attention

# %%
class PositionwiseFeedforwardLayer(nn.Module):
    def __init__(self, hid_dim, pf_dim, dropout):
        super().__init__()
        
        self.fc_1 = nn.Linear(hid_dim, pf_dim)
        self.fc_2 = nn.Linear(pf_dim, hid_dim)
        
        self.dropout = nn.Dropout(dropout)
        
    def forward(self, x):
        
        #x = [batch size, seq len, hid dim]
        
        x = self.dropout(torch.relu(self.fc_1(x)))
        
        #x = [batch size, seq len, pf dim]
        
        x = self.fc_2(x)
        
        #x = [batch size, seq len, hid dim]
        
        return x

# %%
class Decoder(nn.Module):
    def __init__(self, 
                 output_dim, 
                 hid_dim, 
                 n_layers, 
                 n_heads, 
                 pf_dim, 
                 dropout, 
                 device,
                 max_length = 100):
        super().__init__()
        
        self.device = device
        
        self.tok_embedding = nn.Embedding(output_dim, hid_dim)
        self.pos_embedding = nn.Embedding(max_length, hid_dim)
        
        self.layers = nn.ModuleList([DecoderLayer(hid_dim, 
                                                  n_heads, 
                                                  pf_dim, 
                                                  dropout, 
                                                  device)
                                     for _ in range(n_layers)])
        
        self.fc_out = nn.Linear(hid_dim, output_dim)
        
        self.dropout = nn.Dropout(dropout)
        
        self.scale = torch.sqrt(torch.FloatTensor([hid_dim])).to(device)
        
    def forward(self, trg, enc_src, trg_mask, src_mask):
        
        #trg = [batch size, trg len]
        #enc_src = [batch size, src len, hid dim]
        #trg_mask = [batch size, 1, trg len, trg len]
        #src_mask = [batch size, 1, 1, src len]
                
        batch_size = trg.shape[0]
        trg_len = trg.shape[1]
        
        pos = torch.arange(0, trg_len).unsqueeze(0).repeat(batch_size, 1).to(self.device)
                            
        #pos = [batch size, trg len]
            
        trg = self.dropout((self.tok_embedding(trg) * self.scale) + self.pos_embedding(pos))
                
        #trg = [batch size, trg len, hid dim]
        
        for layer in self.layers:
            trg, attention = layer(trg, enc_src, trg_mask, src_mask)
        
        #trg = [batch size, trg len, hid dim]
        #attention = [batch size, n heads, trg len, src len]
        
        output = self.fc_out(trg)
        
        #output = [batch size, trg len, output dim]
            
        return output, attention

# %%
class DecoderLayer(nn.Module):
    def __init__(self, 
                 hid_dim, 
                 n_heads, 
                 pf_dim, 
                 dropout, 
                 device):
        super().__init__()
        
        self.self_attn_layer_norm = nn.LayerNorm(hid_dim)
        self.enc_attn_layer_norm = nn.LayerNorm(hid_dim)
        self.ff_layer_norm = nn.LayerNorm(hid_dim)
        self.self_attention = MultiHeadAttentionLayer(hid_dim, n_heads, dropout, device)
        self.encoder_attention = MultiHeadAttentionLayer(hid_dim, n_heads, dropout, device)
        self.positionwise_feedforward = PositionwiseFeedforwardLayer(hid_dim, 
                                                                     pf_dim, 
                                                                     dropout)
        self.dropout = nn.Dropout(dropout)
        
    def forward(self, trg, enc_src, trg_mask, src_mask):
        
        #trg = [batch size, trg len, hid dim]
        #enc_src = [batch size, src len, hid dim]
        #trg_mask = [batch size, 1, trg len, trg len]
        #src_mask = [batch size, 1, 1, src len]
        
        #self attention
        _trg, _ = self.self_attention(trg, trg, trg, trg_mask)
        
        #dropout, residual connection and layer norm
        trg = self.self_attn_layer_norm(trg + self.dropout(_trg))
            
        #trg = [batch size, trg len, hid dim]
            
        #encoder attention
        _trg, attention = self.encoder_attention(trg, enc_src, enc_src, src_mask)
        # query, key, value
        
        #dropout, residual connection and layer norm
        trg = self.enc_attn_layer_norm(trg + self.dropout(_trg))
                    
        #trg = [batch size, trg len, hid dim]
        
        #positionwise feedforward
        _trg = self.positionwise_feedforward(trg)
        
        #dropout, residual and layer norm
        trg = self.ff_layer_norm(trg + self.dropout(_trg))
        
        #trg = [batch size, trg len, hid dim]
        #attention = [batch size, n heads, trg len, src len]
        
        return trg, attention

# %%
INPUT_DIM = len(sentence.vocab)
OUTPUT_DIM = len(sentence.vocab)
HID_DIM = 256
ENC_LAYERS = 2
DEC_LAYERS = 2
ENC_HEADS = 8
DEC_HEADS = 8
ENC_PF_DIM = 512
DEC_PF_DIM = 512
ENC_DROPOUT = 0.2
DEC_DROPOUT = 0.2

enc = Encoder(INPUT_DIM, 
              HID_DIM, 
              ENC_LAYERS, 
              ENC_HEADS, 
              ENC_PF_DIM, 
              ENC_DROPOUT, 
              device)

dec = Decoder(OUTPUT_DIM, 
              HID_DIM, 
              DEC_LAYERS, 
              DEC_HEADS, 
              DEC_PF_DIM, 
              DEC_DROPOUT, 
              device)

# %%
SRC_PAD_IDX = sentence.vocab.stoi[sentence.pad_token]
TRG_PAD_IDX = sentence.vocab.stoi[sentence.pad_token]

model = Seq2Seq(enc, dec, SRC_PAD_IDX, TRG_PAD_IDX, device).to(device)

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

print(f'The model has {count_parameters(model):,} trainable parameters')
# Out:
# The model has 8,702,863 trainable parameters

# %%
def initialize_weights(m):
    if hasattr(m, 'weight') and m.weight.dim() > 1:
        nn.init.xavier_uniform_(m.weight.data)

# %%
model.apply(initialize_weights);

# %%
LEARNING_RATE = 0.0005

optimizer = torch.optim.Adam(model.parameters(), lr = LEARNING_RATE)

# %% [markdown]
# Since we are dealing with batches of padded sequences, we cannot simply consider all elements of the tensor when calculating loss, so we use ignore index to ignore the padded elements, also this loss function calculates the average negative log likelihood of the elements , so have used the option reduction = 'mean', may be we could used size_average = True as well, since it gave a warning that this option is being deprecated used reduction

# %%
# def maskNLLLoss(inp, target, mask):
#     nTotal = mask.sum()
#     crossEntropy = -torch.log(torch.gather(inp, 1, target.view(-1, 1)).squeeze(1))
#     loss = crossEntropy.masked_select(mask).mean()
#     loss = loss.to(device)
#     return loss, nTotal.item()

# %%
def maskNLLLoss(inp, target,mask):
    criterion = nn.CrossEntropyLoss(ignore_index = mask,reduction='mean')
    loss = criterion(inp, target)
    return loss

# %%
def train(model, iterator, optimizer, criterion, clip):
    
    model.train()
    
    epoch_loss = 0
    
    for i, batch in enumerate(iterator):
        
        src = batch.input_sentence
        trg = batch.output_sentence
        
        optimizer.zero_grad()
        
        output, _ = model(src, trg[:,:-1])

                
        #output = [batch size, trg len - 1, output dim]
        #trg = [batch size, trg len]
            
        output_dim = output.shape[-1]

            
        output = output.contiguous().view(-1, output_dim)
        trg = trg[:,1:].contiguous().view(-1)
                
        #output = [batch size * trg len - 1, output dim]
        #trg = [batch size * trg len - 1]
            
        # loss = criterion(output, trg)
        loss = maskNLLLoss(output, trg,model.trg_pad_idx)
        
        loss.backward()
        
        torch.nn.utils.clip_grad_norm_(model.parameters(), clip)
        
        optimizer.step()
        
        epoch_loss += loss.item()
        
    return epoch_loss / len(iterator)

# %%
def evaluate(model, iterator, criterion):
    
    model.eval()
    
    epoch_loss = 0
    
    with torch.no_grad():
    
        for i, batch in enumerate(iterator):

            src = batch.input_sentence
            trg = batch.output_sentence

            output, _ = model(src, trg[:,:-1])
            
            #output = [batch size, trg len - 1, output dim]
            #trg = [batch size, trg len]
            
            output_dim = output.shape[-1]
           
            
            output = output.contiguous().view(-1, output_dim)
            trg = trg[:,1:].contiguous().view(-1)
            
            #output = [batch size * trg len - 1, output dim]
            #trg = [batch size * trg len - 1]
            
            
            #loss = criterion(output, trg)
            loss = maskNLLLoss(output, trg,model.trg_pad_idx)

            #loss,_ = maskNLLLoss(output, trg, mask)

            epoch_loss += loss.item()
        
    return epoch_loss / len(iterator)

# %%
import time
def epoch_time(start_time, end_time):
    elapsed_time = end_time - start_time
    elapsed_mins = int(elapsed_time / 60)
    elapsed_secs = int(elapsed_time - (elapsed_mins * 60))
    return elapsed_mins, elapsed_secs

# %%
N_EPOCHS = 1000
CLIP = 1

best_valid_loss = float('inf')

for epoch in range(N_EPOCHS):
    
    start_time = time.time()
    
    train_loss = train(model, train_iterator, optimizer, maskNLLLoss, CLIP)
    valid_loss = evaluate(model, valid_iterator, maskNLLLoss)
    
    end_time = time.time()
    
    epoch_mins, epoch_secs = epoch_time(start_time, end_time)
    
    if valid_loss < best_valid_loss:
        best_valid_loss = valid_loss
        torch.save(model.state_dict(), 'tut1000-model.pt')
    
    print(f'Epoch: {epoch+1:02} | Time: {epoch_mins}m {epoch_secs}s')
    print(f'\tTrain Loss: {train_loss:.3f} | Train PPL: {math.exp(train_loss):7.3f}')
    print(f'\t Val. Loss: {valid_loss:.3f} |  Val. PPL: {math.exp(valid_loss):7.3f}')
# Out:
# Epoch: 01 | Time: 0m 50s
# 	Train Loss: 4.033 | Train PPL:  56.411
# 	 Val. Loss: 3.697 |  Val. PPL:  40.341
# Epoch: 02 | Time: 0m 50s
# 	Train Loss: 3.551 | Train PPL:  34.834
# 	 Val. Loss: 3.581 |  Val. PPL:  35.898
# Epoch: 03 | Time: 0m 50s
# 	Train Loss: 3.381 | Train PPL:  29.390
# 	 Val. Loss: 3.561 |  Val. PPL:  35.190
# Epoch: 04 | Time: 0m 50s
# 	Train Loss: 3.253 | Train PPL:  25.870
# 	 Val. Loss: 3.557 |  Val. PPL:  35.046
# Epoch: 05 | Time: 0m 50s
# 	Train Loss: 3.141 | Train PPL:  23.122
# 	 Val. Loss: 3.553 |  Val. PPL:  34.931
# Epoch: 06 | Time: 0m 50s
# 	Train Loss: 3.041 | Train PPL:  20.918
# 	 Val. Loss: 3.577 |  Val. PPL:  35.749
# Epoch: 07 | Time: 0m 50s
# 	Train Loss: 2.954 | Train PPL:  19.190
# 	 Val. Loss: 3.607 |  Val. PPL:  36.852
# Epoch: 08 | Time: 0m 50s
# 	Train Loss: 2.875 | Train PPL:  17.722
# 	 Val. Loss: 3.641 |  Val. PPL:  38.147
# Epoch: 09 | Time: 0m 50s
# 	Train Loss: 2.804 | Train PPL:  16.515
# 	 Val. Loss: 3.689 |  Val. PPL:  39.985
# Epoch: 10 | Time: 0m 50s
# 	Train Loss: 2.740 | Train PPL:  15.482
# 	 Val. Loss: 3.729 |  Val. PPL:  41.658
# Epoch: 11 | Time: 0m 50s
# 	Train Loss: 2.684 | Train PPL:  14.651
# 	 Val. Loss: 3.767 |  Val. PPL:  43.259
# Epoch: 12 | Time: 0m 50s
# 	Train Loss: 2.633 | Train PPL:  13.919
# 	 Val. Loss: 3.803 |  Val. PPL:  44.852
# Epoch: 13 | Time: 0m 50s
# 	Train Loss: 2.588 | Train PPL:  13.309
# 	 Val. Loss: 3.831 |  Val. PPL:  46.113
# Epoch: 14 | Time: 0m 50s
# 	Train Loss: 2.547 | Train PPL:  12.767
# 	 Val. Loss: 3.859 |  Val. PPL:  47.426
# Epoch: 15 | Time: 0m 50s
# 	Train Loss: 2.507 | Train PPL:  12.268
# 	 Val. Loss: 3.895 |  Val. PPL:  49.132
# Epoch: 16 | Time: 0m 50s
# 	Train Loss: 2.471 | Train PPL:  11.832
# 	 Val. Loss: 3.923 |  Val. PPL:  50.554
# Epoch: 17 | Time: 0m 50s
# 	Train Loss: 2.436 | Train PPL:  11.433
# 	 Val. Loss: 3.969 |  Val. PPL:  52.926
# Epoch: 18 | Time: 0m 50s
# 	Train Loss: 2.405 | Train PPL:  11.082
# 	 Val. Loss: 3.981 |  Val. PPL:  53.570
# Epoch: 19 | Time: 0m 50s
# 	Train Loss: 2.376 | Train PPL:  10.763
# 	 Val. Loss: 4.031 |  Val. PPL:  56.303
# Epoch: 20 | Time: 0m 50s
# 	Train Loss: 2.351 | Train PPL:  10.498
# 	 Val. Loss: 4.048 |  Val. PPL:  57.262
# Epoch: 21 | Time: 0m 50s
# 	Train Loss: 2.322 | Train PPL:  10.198
# 	 Val. Loss: 4.071 |  Val. PPL:  58.632
# Epoch: 22 | Time: 0m 50s
# 	Train Loss: 2.301 | Train PPL:   9.983
# 	 Val. Loss: 4.100 |  Val. PPL:  60.351
# Epoch: 23 | Time: 0m 50s
# 	Train Loss: 2.279 | Train PPL:   9.766
# 	 Val. Loss: 4.126 |  Val. PPL:  61.920
# Epoch: 24 | Time: 0m 50s
# 	Train Loss: 2.256 | Train PPL:   9.549
# 	 Val. Loss: 4.167 |  Val. PPL:  64.519
# Epoch: 25 | Time: 0m 50s
# 	Train Loss: 2.239 | Train PPL:   9.382
# 	 Val. Loss: 4.166 |  Val. PPL:  64.476
# Epoch: 26 | Time: 0m 50s
# 	Train Loss: 2.219 | Train PPL:   9.199
# 	 Val. Loss: 4.181 |  Val. PPL:  65.413
# Epoch: 27 | Time: 0m 50s
# 	Train Loss: 2.202 | Train PPL:   9.041
# 	 Val. Loss: 4.241 |  Val. PPL:  69.496
# Epoch: 28 | Time: 0m 50s
# 	Train Loss: 2.184 | Train PPL:   8.883
# 	 Val. Loss: 4.247 |  Val. PPL:  69.873
# Epoch: 29 | Time: 0m 50s
# 	Train Loss: 2.167 | Train PPL:   8.736
# 	 Val. Loss: 4.259 |  Val. PPL:  70.754
# Epoch: 30 | Time: 0m 50s
# 	Train Loss: 2.151 | Train PPL:   8.590
# 	 Val. Loss: 4.284 |  Val. PPL:  72.521
# Epoch: 31 | Time: 0m 50s
# 	Train Loss: 2.134 | Train PPL:   8.449
# 	 Val. Loss: 4.317 |  Val. PPL:  74.974
# Epoch: 32 | Time: 0m 50s
# 	Train Loss: 2.122 | Train PPL:   8.346
# 	 Val. Loss: 4.328 |  Val. PPL:  75.797
# Epoch: 33 | Time: 0m 50s
# 	Train Loss: 2.107 | Train PPL:   8.226
# 	 Val. Loss: 4.404 |  Val. PPL:  81.763
# Epoch: 34 | Time: 0m 50s
# 	Train Loss: 2.097 | Train PPL:   8.142
# 	 Val. Loss: 4.383 |  Val. PPL:  80.065
# Epoch: 35 | Time: 0m 50s
# 	Train Loss: 2.081 | Train PPL:   8.013
# 	 Val. Loss: 4.376 |  Val. PPL:  79.555
# Epoch: 36 | Time: 0m 50s
# 	Train Loss: 2.069 | Train PPL:   7.916
# 	 Val. Loss: 4.372 |  Val. PPL:  79.232
# Epoch: 37 | Time: 0m 50s
# 	Train Loss: 2.060 | Train PPL:   7.844
# 	 Val. Loss: 4.425 |  Val. PPL:  83.484
# Epoch: 38 | Time: 0m 50s
# 	Train Loss: 2.049 | Train PPL:   7.757
# 	 Val. Loss: 4.428 |  Val. PPL:  83.724
# Epoch: 39 | Time: 0m 50s
# 	Train Loss: 2.034 | Train PPL:   7.642
# 	 Val. Loss: 4.477 |  Val. PPL:  87.959
# Epoch: 40 | Time: 0m 50s
# 	Train Loss: 2.027 | Train PPL:   7.594
# 	 Val. Loss: 4.472 |  Val. PPL:  87.542
# Epoch: 41 | Time: 0m 50s
# 	Train Loss: 2.018 | Train PPL:   7.523
# 	 Val. Loss: 4.475 |  Val. PPL:  87.828
# Epoch: 42 | Time: 0m 50s
# 	Train Loss: 2.006 | Train PPL:   7.437
# 	 Val. Loss: 4.526 |  Val. PPL:  92.412
# Epoch: 43 | Time: 0m 50s
# 	Train Loss: 1.995 | Train PPL:   7.353
# 	 Val. Loss: 4.523 |  Val. PPL:  92.146
# Epoch: 44 | Time: 0m 50s
# 	Train Loss: 1.989 | Train PPL:   7.307
# 	 Val. Loss: 4.535 |  Val. PPL:  93.217
# Epoch: 45 | Time: 0m 50s
# 	Train Loss: 1.978 | Train PPL:   7.230
# 	 Val. Loss: 4.577 |  Val. PPL:  97.241
# Epoch: 46 | Time: 0m 50s
# 	Train Loss: 1.970 | Train PPL:   7.167
# 	 Val. Loss: 4.597 |  Val. PPL:  99.189
# Epoch: 47 | Time: 0m 50s
# 	Train Loss: 1.961 | Train PPL:   7.107
# 	 Val. Loss: 4.584 |  Val. PPL:  97.907
# Epoch: 48 | Time: 0m 50s
# 	Train Loss: 1.953 | Train PPL:   7.053
# 	 Val. Loss: 4.607 |  Val. PPL: 100.213
# Epoch: 49 | Time: 0m 50s
# 	Train Loss: 1.945 | Train PPL:   6.992
# 	 Val. Loss: 4.590 |  Val. PPL:  98.491
# Epoch: 50 | Time: 0m 50s
# 	Train Loss: 1.936 | Train PPL:   6.928
# 	 Val. Loss: 4.614 |  Val. PPL: 100.927
# Epoch: 51 | Time: 0m 50s
# 	Train Loss: 1.932 | Train PPL:   6.901
# 	 Val. Loss: 4.649 |  Val. PPL: 104.468
# Epoch: 52 | Time: 0m 50s
# 	Train Loss: 1.924 | Train PPL:   6.851
# 	 Val. Loss: 4.681 |  Val. PPL: 107.873
# Epoch: 53 | Time: 0m 50s
# 	Train Loss: 1.915 | Train PPL:   6.788
# 	 Val. Loss: 4.649 |  Val. PPL: 104.506
# Epoch: 54 | Time: 0m 50s
# 	Train Loss: 1.910 | Train PPL:   6.751
# 	 Val. Loss: 4.667 |  Val. PPL: 106.409
# Epoch: 55 | Time: 0m 50s
# 	Train Loss: 1.901 | Train PPL:   6.692
# 	 Val. Loss: 4.652 |  Val. PPL: 104.829
# Epoch: 56 | Time: 0m 50s
# 	Train Loss: 1.895 | Train PPL:   6.652
# 	 Val. Loss: 4.703 |  Val. PPL: 110.325
# Epoch: 57 | Time: 0m 50s
# 	Train Loss: 1.890 | Train PPL:   6.622
# 	 Val. Loss: 4.722 |  Val. PPL: 112.360
# Epoch: 58 | Time: 0m 50s
# 	Train Loss: 1.883 | Train PPL:   6.570
# 	 Val. Loss: 4.697 |  Val. PPL: 109.646
# Epoch: 59 | Time: 0m 50s
# 	Train Loss: 1.879 | Train PPL:   6.545
# 	 Val. Loss: 4.748 |  Val. PPL: 115.311
# Epoch: 60 | Time: 0m 50s
# 	Train Loss: 1.870 | Train PPL:   6.489
# 	 Val. Loss: 4.743 |  Val. PPL: 114.827
# Epoch: 61 | Time: 0m 50s
# 	Train Loss: 1.866 | Train PPL:   6.462
# 	 Val. Loss: 4.787 |  Val. PPL: 119.956
# Epoch: 62 | Time: 0m 50s
# 	Train Loss: 1.861 | Train PPL:   6.430
# 	 Val. Loss: 4.729 |  Val. PPL: 113.176
# Epoch: 63 | Time: 0m 50s
# 	Train Loss: 1.855 | Train PPL:   6.395
# 	 Val. Loss: 4.759 |  Val. PPL: 116.576
# Epoch: 64 | Time: 0m 50s
# 	Train Loss: 1.850 | Train PPL:   6.362
# 	 Val. Loss: 4.781 |  Val. PPL: 119.230
# Epoch: 65 | Time: 0m 50s
# 	Train Loss: 1.845 | Train PPL:   6.325
# 	 Val. Loss: 4.822 |  Val. PPL: 124.199
# Epoch: 66 | Time: 0m 50s
# 	Train Loss: 1.838 | Train PPL:   6.286
# 	 Val. Loss: 4.793 |  Val. PPL: 120.712
# Epoch: 67 | Time: 0m 50s
# 	Train Loss: 1.834 | Train PPL:   6.258
# 	 Val. Loss: 4.830 |  Val. PPL: 125.201
# Epoch: 68 | Time: 0m 50s
# 	Train Loss: 1.829 | Train PPL:   6.230
# 	 Val. Loss: 4.851 |  Val. PPL: 127.909
# Epoch: 69 | Time: 0m 50s
# 	Train Loss: 1.826 | Train PPL:   6.209
# 	 Val. Loss: 4.816 |  Val. PPL: 123.435
# Epoch: 70 | Time: 0m 50s
# 	Train Loss: 1.820 | Train PPL:   6.174
# 	 Val. Loss: 4.845 |  Val. PPL: 127.091
# Epoch: 71 | Time: 0m 50s
# 	Train Loss: 1.818 | Train PPL:   6.157
# 	 Val. Loss: 4.789 |  Val. PPL: 120.170
# Epoch: 72 | Time: 0m 50s
# 	Train Loss: 1.812 | Train PPL:   6.121
# 	 Val. Loss: 4.804 |  Val. PPL: 122.046
# Epoch: 73 | Time: 0m 50s
# 	Train Loss: 1.806 | Train PPL:   6.085
# 	 Val. Loss: 4.863 |  Val. PPL: 129.364
# Epoch: 74 | Time: 0m 50s
# 	Train Loss: 1.801 | Train PPL:   6.055
# 	 Val. Loss: 4.826 |  Val. PPL: 124.658
# Epoch: 75 | Time: 0m 50s
# 	Train Loss: 1.799 | Train PPL:   6.046
# 	 Val. Loss: 4.893 |  Val. PPL: 133.330
# Epoch: 76 | Time: 0m 50s
# 	Train Loss: 1.793 | Train PPL:   6.005
# 	 Val. Loss: 4.872 |  Val. PPL: 130.604
# Epoch: 77 | Time: 0m 50s
# 	Train Loss: 1.793 | Train PPL:   6.006
# 	 Val. Loss: 4.907 |  Val. PPL: 135.283
# Epoch: 78 | Time: 0m 50s
# 	Train Loss: 1.785 | Train PPL:   5.961
# 	 Val. Loss: 4.873 |  Val. PPL: 130.685
# Epoch: 79 | Time: 0m 50s
# 	Train Loss: 1.780 | Train PPL:   5.928
# 	 Val. Loss: 4.878 |  Val. PPL: 131.310
# Epoch: 80 | Time: 0m 50s
# 	Train Loss: 1.776 | Train PPL:   5.906
# 	 Val. Loss: 4.918 |  Val. PPL: 136.675
# Epoch: 81 | Time: 0m 50s
# 	Train Loss: 1.775 | Train PPL:   5.897
# 	 Val. Loss: 4.897 |  Val. PPL: 133.841
# Epoch: 82 | Time: 0m 50s
# 	Train Loss: 1.768 | Train PPL:   5.859
# 	 Val. Loss: 4.911 |  Val. PPL: 135.836
# Epoch: 83 | Time: 0m 50s
# 	Train Loss: 1.764 | Train PPL:   5.833
# 	 Val. Loss: 4.929 |  Val. PPL: 138.283
# Epoch: 84 | Time: 0m 50s
# 	Train Loss: 1.761 | Train PPL:   5.820
# 	 Val. Loss: 4.934 |  Val. PPL: 138.951
# Epoch: 85 | Time: 0m 50s
# 	Train Loss: 1.756 | Train PPL:   5.792
# 	 Val. Loss: 4.923 |  Val. PPL: 137.444
# Epoch: 86 | Time: 0m 50s
# 	Train Loss: 1.757 | Train PPL:   5.795
# 	 Val. Loss: 4.909 |  Val. PPL: 135.552
# Epoch: 87 | Time: 0m 50s
# 	Train Loss: 1.749 | Train PPL:   5.751
# 	 Val. Loss: 4.939 |  Val. PPL: 139.688
# Epoch: 88 | Time: 0m 50s
# 	Train Loss: 1.745 | Train PPL:   5.727
# 	 Val. Loss: 4.952 |  Val. PPL: 141.452
# Epoch: 89 | Time: 0m 50s
# 	Train Loss: 1.744 | Train PPL:   5.719
# 	 Val. Loss: 4.958 |  Val. PPL: 142.345
# Epoch: 90 | Time: 0m 50s
# 	Train Loss: 1.741 | Train PPL:   5.701
# 	 Val. Loss: 4.923 |  Val. PPL: 137.354
# Epoch: 91 | Time: 0m 50s
# 	Train Loss: 1.739 | Train PPL:   5.690
# 	 Val. Loss: 4.939 |  Val. PPL: 139.700
# Epoch: 92 | Time: 0m 50s
# 	Train Loss: 1.735 | Train PPL:   5.670
# 	 Val. Loss: 5.008 |  Val. PPL: 149.604
# Epoch: 93 | Time: 0m 50s
# 	Train Loss: 1.729 | Train PPL:   5.634
# 	 Val. Loss: 4.951 |  Val. PPL: 141.363
# Epoch: 94 | Time: 0m 51s
# 	Train Loss: 1.727 | Train PPL:   5.626
# 	 Val. Loss: 4.974 |  Val. PPL: 144.588
# Epoch: 95 | Time: 0m 50s
# 	Train Loss: 1.723 | Train PPL:   5.601
# 	 Val. Loss: 4.954 |  Val. PPL: 141.708
# Epoch: 96 | Time: 0m 50s
# 	Train Loss: 1.724 | Train PPL:   5.607
# 	 Val. Loss: 4.979 |  Val. PPL: 145.332
# Epoch: 97 | Time: 0m 50s
# 	Train Loss: 1.719 | Train PPL:   5.578
# 	 Val. Loss: 4.964 |  Val. PPL: 143.100
# Epoch: 98 | Time: 0m 50s
# 	Train Loss: 1.718 | Train PPL:   5.571
# 	 Val. Loss: 4.996 |  Val. PPL: 147.887
# Epoch: 99 | Time: 0m 50s
# 	Train Loss: 1.709 | Train PPL:   5.524
# 	 Val. Loss: 4.985 |  Val. PPL: 146.220
# Epoch: 100 | Time: 0m 50s
# 	Train Loss: 1.707 | Train PPL:   5.512
# 	 Val. Loss: 5.005 |  Val. PPL: 149.224
# Epoch: 101 | Time: 0m 50s
# 	Train Loss: 1.706 | Train PPL:   5.508
# 	 Val. Loss: 5.012 |  Val. PPL: 150.200
# Epoch: 102 | Time: 0m 50s
# 	Train Loss: 1.701 | Train PPL:   5.482
# 	 Val. Loss: 4.994 |  Val. PPL: 147.456
# Epoch: 103 | Time: 0m 50s
# 	Train Loss: 1.700 | Train PPL:   5.476
# 	 Val. Loss: 5.000 |  Val. PPL: 148.382
# Epoch: 104 | Time: 0m 50s
# 	Train Loss: 1.695 | Train PPL:   5.448
# 	 Val. Loss: 5.033 |  Val. PPL: 153.343
# Epoch: 105 | Time: 0m 50s
# 	Train Loss: 1.694 | Train PPL:   5.441
# 	 Val. Loss: 5.018 |  Val. PPL: 151.085
# Epoch: 106 | Time: 0m 50s
# 	Train Loss: 1.688 | Train PPL:   5.410
# 	 Val. Loss: 5.045 |  Val. PPL: 155.202
# Epoch: 107 | Time: 0m 50s
# 	Train Loss: 1.686 | Train PPL:   5.398
# 	 Val. Loss: 5.050 |  Val. PPL: 156.058
# Epoch: 108 | Time: 0m 50s
# 	Train Loss: 1.685 | Train PPL:   5.391
# 	 Val. Loss: 5.109 |  Val. PPL: 165.505
# Epoch: 109 | Time: 0m 50s
# 	Train Loss: 1.686 | Train PPL:   5.396
# 	 Val. Loss: 5.044 |  Val. PPL: 155.098
# Epoch: 110 | Time: 0m 50s
# 	Train Loss: 1.681 | Train PPL:   5.373
# 	 Val. Loss: 5.044 |  Val. PPL: 155.121
# Epoch: 111 | Time: 0m 50s
# 	Train Loss: 1.677 | Train PPL:   5.351
# 	 Val. Loss: 5.057 |  Val. PPL: 157.070
# Epoch: 112 | Time: 0m 50s
# 	Train Loss: 1.675 | Train PPL:   5.338
# 	 Val. Loss: 5.068 |  Val. PPL: 158.928
# Epoch: 113 | Time: 0m 50s
# 	Train Loss: 1.673 | Train PPL:   5.326
# 	 Val. Loss: 5.027 |  Val. PPL: 152.464
# Epoch: 114 | Time: 0m 50s
# 	Train Loss: 1.670 | Train PPL:   5.310
# 	 Val. Loss: 5.101 |  Val. PPL: 164.235
# Epoch: 115 | Time: 0m 50s
# 	Train Loss: 1.668 | Train PPL:   5.303
# 	 Val. Loss: 5.049 |  Val. PPL: 155.892
# Epoch: 116 | Time: 0m 50s
# 	Train Loss: 1.669 | Train PPL:   5.307
# 	 Val. Loss: 5.082 |  Val. PPL: 161.036
# Epoch: 117 | Time: 0m 50s
# 	Train Loss: 1.664 | Train PPL:   5.281
# 	 Val. Loss: 5.150 |  Val. PPL: 172.390
# Epoch: 118 | Time: 0m 50s
# 	Train Loss: 1.658 | Train PPL:   5.248
# 	 Val. Loss: 5.102 |  Val. PPL: 164.414
# Epoch: 119 | Time: 0m 50s
# 	Train Loss: 1.656 | Train PPL:   5.241
# 	 Val. Loss: 5.058 |  Val. PPL: 157.329
# Epoch: 120 | Time: 0m 50s
# 	Train Loss: 1.658 | Train PPL:   5.249
# 	 Val. Loss: 5.092 |  Val. PPL: 162.786
# Epoch: 121 | Time: 0m 50s
# 	Train Loss: 1.654 | Train PPL:   5.229
# 	 Val. Loss: 5.064 |  Val. PPL: 158.237
# Epoch: 122 | Time: 0m 50s
# 	Train Loss: 1.651 | Train PPL:   5.214
# 	 Val. Loss: 5.114 |  Val. PPL: 166.355
# Epoch: 123 | Time: 0m 50s
# 	Train Loss: 1.652 | Train PPL:   5.215
# 	 Val. Loss: 5.134 |  Val. PPL: 169.728
# Epoch: 124 | Time: 0m 50s
# 	Train Loss: 1.645 | Train PPL:   5.181
# 	 Val. Loss: 5.125 |  Val. PPL: 168.136
# Epoch: 125 | Time: 0m 50s
# 	Train Loss: 1.646 | Train PPL:   5.186
# 	 Val. Loss: 5.145 |  Val. PPL: 171.598
# Epoch: 126 | Time: 0m 50s
# 	Train Loss: 1.642 | Train PPL:   5.165
# 	 Val. Loss: 5.097 |  Val. PPL: 163.522
# Epoch: 127 | Time: 0m 50s
# 	Train Loss: 1.645 | Train PPL:   5.182
# 	 Val. Loss: 5.097 |  Val. PPL: 163.585
# Epoch: 128 | Time: 0m 50s
# 	Train Loss: 1.637 | Train PPL:   5.142
# 	 Val. Loss: 5.202 |  Val. PPL: 181.664
# Epoch: 129 | Time: 0m 50s
# 	Train Loss: 1.634 | Train PPL:   5.122
# 	 Val. Loss: 5.147 |  Val. PPL: 171.957
# Epoch: 130 | Time: 0m 50s
# 	Train Loss: 1.634 | Train PPL:   5.126
# 	 Val. Loss: 5.180 |  Val. PPL: 177.695
# Epoch: 131 | Time: 0m 50s
# 	Train Loss: 1.632 | Train PPL:   5.113
# 	 Val. Loss: 5.213 |  Val. PPL: 183.628
# Epoch: 132 | Time: 0m 50s
# 	Train Loss: 1.627 | Train PPL:   5.090
# 	 Val. Loss: 5.128 |  Val. PPL: 168.745
# Epoch: 133 | Time: 0m 50s
# 	Train Loss: 1.628 | Train PPL:   5.095
# 	 Val. Loss: 5.189 |  Val. PPL: 179.261
# Epoch: 134 | Time: 0m 50s
# 	Train Loss: 1.627 | Train PPL:   5.088
# 	 Val. Loss: 5.188 |  Val. PPL: 179.153
# Epoch: 135 | Time: 0m 50s
# 	Train Loss: 1.624 | Train PPL:   5.073
# 	 Val. Loss: 5.168 |  Val. PPL: 175.641
# Epoch: 136 | Time: 0m 50s
# 	Train Loss: 1.620 | Train PPL:   5.051
# 	 Val. Loss: 5.180 |  Val. PPL: 177.680
# Epoch: 137 | Time: 0m 50s
# 	Train Loss: 1.618 | Train PPL:   5.042
# 	 Val. Loss: 5.154 |  Val. PPL: 173.190
# Epoch: 138 | Time: 0m 50s
# 	Train Loss: 1.618 | Train PPL:   5.042
# 	 Val. Loss: 5.209 |  Val. PPL: 182.940
# Epoch: 139 | Time: 0m 50s
# 	Train Loss: 1.615 | Train PPL:   5.029
# 	 Val. Loss: 5.194 |  Val. PPL: 180.149
# Epoch: 140 | Time: 0m 50s
# 	Train Loss: 1.612 | Train PPL:   5.014
# 	 Val. Loss: 5.190 |  Val. PPL: 179.420
# Epoch: 141 | Time: 0m 50s
# 	Train Loss: 1.611 | Train PPL:   5.008
# 	 Val. Loss: 5.177 |  Val. PPL: 177.158
# Epoch: 142 | Time: 0m 50s
# 	Train Loss: 1.608 | Train PPL:   4.993
# 	 Val. Loss: 5.191 |  Val. PPL: 179.731
# Epoch: 143 | Time: 0m 50s
# 	Train Loss: 1.605 | Train PPL:   4.977
# 	 Val. Loss: 5.206 |  Val. PPL: 182.328
# Epoch: 144 | Time: 0m 50s
# 	Train Loss: 1.603 | Train PPL:   4.966
# 	 Val. Loss: 5.186 |  Val. PPL: 178.694
# Epoch: 145 | Time: 0m 50s
# 	Train Loss: 1.604 | Train PPL:   4.975
# 	 Val. Loss: 5.257 |  Val. PPL: 191.957
# Epoch: 146 | Time: 0m 50s
# 	Train Loss: 1.600 | Train PPL:   4.952
# 	 Val. Loss: 5.190 |  Val. PPL: 179.383
# Epoch: 147 | Time: 0m 50s
# 	Train Loss: 1.600 | Train PPL:   4.954
# 	 Val. Loss: 5.257 |  Val. PPL: 191.965
# Epoch: 148 | Time: 0m 50s
# 	Train Loss: 1.598 | Train PPL:   4.941
# 	 Val. Loss: 5.179 |  Val. PPL: 177.472
# Epoch: 149 | Time: 0m 50s
# 	Train Loss: 1.601 | Train PPL:   4.958
# 	 Val. Loss: 5.249 |  Val. PPL: 190.415
# Epoch: 150 | Time: 0m 50s
# 	Train Loss: 1.598 | Train PPL:   4.944
# 	 Val. Loss: 5.232 |  Val. PPL: 187.129
# Epoch: 151 | Time: 0m 50s
# 	Train Loss: 1.597 | Train PPL:   4.936
# 	 Val. Loss: 5.245 |  Val. PPL: 189.542
# Epoch: 152 | Time: 0m 50s
# 	Train Loss: 1.597 | Train PPL:   4.940
# 	 Val. Loss: 5.229 |  Val. PPL: 186.554
# Epoch: 153 | Time: 0m 50s
# 	Train Loss: 1.592 | Train PPL:   4.915
# 	 Val. Loss: 5.213 |  Val. PPL: 183.688
# Epoch: 154 | Time: 0m 50s
# 	Train Loss: 1.587 | Train PPL:   4.888
# 	 Val. Loss: 5.220 |  Val. PPL: 184.986
# Epoch: 155 | Time: 0m 50s
# 	Train Loss: 1.587 | Train PPL:   4.889
# 	 Val. Loss: 5.224 |  Val. PPL: 185.602
# Epoch: 156 | Time: 0m 50s
# 	Train Loss: 1.588 | Train PPL:   4.894
# 	 Val. Loss: 5.222 |  Val. PPL: 185.274
# Epoch: 157 | Time: 0m 50s
# 	Train Loss: 1.584 | Train PPL:   4.872
# 	 Val. Loss: 5.257 |  Val. PPL: 191.840
# Epoch: 158 | Time: 0m 50s
# 	Train Loss: 1.581 | Train PPL:   4.858
# 	 Val. Loss: 5.236 |  Val. PPL: 187.993
# Epoch: 159 | Time: 0m 50s
# 	Train Loss: 1.581 | Train PPL:   4.861
# 	 Val. Loss: 5.219 |  Val. PPL: 184.807
# Epoch: 160 | Time: 0m 50s
# 	Train Loss: 1.577 | Train PPL:   4.838
# 	 Val. Loss: 5.281 |  Val. PPL: 196.596
# Epoch: 161 | Time: 0m 50s
# 	Train Loss: 1.576 | Train PPL:   4.835
# 	 Val. Loss: 5.241 |  Val. PPL: 188.787
# Epoch: 162 | Time: 0m 50s
# 	Train Loss: 1.577 | Train PPL:   4.841
# 	 Val. Loss: 5.245 |  Val. PPL: 189.580
# Epoch: 163 | Time: 0m 50s
# 	Train Loss: 1.572 | Train PPL:   4.815
# 	 Val. Loss: 5.285 |  Val. PPL: 197.315
# Epoch: 164 | Time: 0m 50s
# 	Train Loss: 1.573 | Train PPL:   4.821
# 	 Val. Loss: 5.282 |  Val. PPL: 196.677
# Epoch: 165 | Time: 0m 50s
# 	Train Loss: 1.570 | Train PPL:   4.807
# 	 Val. Loss: 5.264 |  Val. PPL: 193.269
# Epoch: 166 | Time: 0m 50s
# 	Train Loss: 1.567 | Train PPL:   4.792
# 	 Val. Loss: 5.256 |  Val. PPL: 191.627
# Epoch: 167 | Time: 0m 50s
# 	Train Loss: 1.567 | Train PPL:   4.791
# 	 Val. Loss: 5.260 |  Val. PPL: 192.485
# Epoch: 168 | Time: 0m 50s
# 	Train Loss: 1.563 | Train PPL:   4.774
# 	 Val. Loss: 5.284 |  Val. PPL: 197.083
# Epoch: 169 | Time: 0m 50s
# 	Train Loss: 1.566 | Train PPL:   4.786
# 	 Val. Loss: 5.290 |  Val. PPL: 198.245
# Epoch: 170 | Time: 0m 50s
# 	Train Loss: 1.562 | Train PPL:   4.769
# 	 Val. Loss: 5.290 |  Val. PPL: 198.358
# Epoch: 171 | Time: 0m 50s
# 	Train Loss: 1.559 | Train PPL:   4.755
# 	 Val. Loss: 5.296 |  Val. PPL: 199.571
# Epoch: 172 | Time: 0m 50s
# 	Train Loss: 1.557 | Train PPL:   4.745
# 	 Val. Loss: 5.298 |  Val. PPL: 200.029
# Epoch: 173 | Time: 0m 50s
# 	Train Loss: 1.558 | Train PPL:   4.750
# 	 Val. Loss: 5.277 |  Val. PPL: 195.792
# Epoch: 174 | Time: 0m 50s
# 	Train Loss: 1.554 | Train PPL:   4.732
# 	 Val. Loss: 5.260 |  Val. PPL: 192.421
# Epoch: 175 | Time: 0m 50s
# 	Train Loss: 1.553 | Train PPL:   4.725
# 	 Val. Loss: 5.311 |  Val. PPL: 202.605
# Epoch: 176 | Time: 0m 50s
# 	Train Loss: 1.551 | Train PPL:   4.716
# 	 Val. Loss: 5.256 |  Val. PPL: 191.709
# Epoch: 177 | Time: 0m 50s
# 	Train Loss: 1.549 | Train PPL:   4.707
# 	 Val. Loss: 5.357 |  Val. PPL: 212.171
# Epoch: 178 | Time: 0m 50s
# 	Train Loss: 1.549 | Train PPL:   4.705
# 	 Val. Loss: 5.326 |  Val. PPL: 205.714
# Epoch: 179 | Time: 0m 50s
# 	Train Loss: 1.546 | Train PPL:   4.693
# 	 Val. Loss: 5.306 |  Val. PPL: 201.628
# Epoch: 180 | Time: 0m 50s
# 	Train Loss: 1.550 | Train PPL:   4.711
# 	 Val. Loss: 5.312 |  Val. PPL: 202.811
# Epoch: 181 | Time: 0m 50s
# 	Train Loss: 1.544 | Train PPL:   4.684
# 	 Val. Loss: 5.252 |  Val. PPL: 190.996
# Epoch: 182 | Time: 0m 50s
# 	Train Loss: 1.546 | Train PPL:   4.693
# 	 Val. Loss: 5.275 |  Val. PPL: 195.389
# Epoch: 183 | Time: 0m 50s
# 	Train Loss: 1.541 | Train PPL:   4.669
# 	 Val. Loss: 5.301 |  Val. PPL: 200.515
# Epoch: 184 | Time: 0m 50s
# 	Train Loss: 1.545 | Train PPL:   4.686
# 	 Val. Loss: 5.348 |  Val. PPL: 210.176
# Epoch: 185 | Time: 0m 50s
# 	Train Loss: 1.541 | Train PPL:   4.670
# 	 Val. Loss: 5.322 |  Val. PPL: 204.766
# Epoch: 186 | Time: 0m 50s
# 	Train Loss: 1.539 | Train PPL:   4.659
# 	 Val. Loss: 5.335 |  Val. PPL: 207.465
# Epoch: 187 | Time: 0m 50s
# 	Train Loss: 1.538 | Train PPL:   4.654
# 	 Val. Loss: 5.289 |  Val. PPL: 198.213
# Epoch: 188 | Time: 0m 50s
# 	Train Loss: 1.535 | Train PPL:   4.639
# 	 Val. Loss: 5.288 |  Val. PPL: 198.041
# Epoch: 189 | Time: 0m 50s
# 	Train Loss: 1.533 | Train PPL:   4.633
# 	 Val. Loss: 5.310 |  Val. PPL: 202.347
# Epoch: 190 | Time: 0m 51s
# 	Train Loss: 1.531 | Train PPL:   4.623
# 	 Val. Loss: 5.306 |  Val. PPL: 201.567
# Epoch: 191 | Time: 0m 50s
# 	Train Loss: 1.531 | Train PPL:   4.622
# 	 Val. Loss: 5.334 |  Val. PPL: 207.326
# Epoch: 192 | Time: 0m 50s
# 	Train Loss: 1.529 | Train PPL:   4.614
# 	 Val. Loss: 5.329 |  Val. PPL: 206.324
# Epoch: 193 | Time: 0m 50s
# 	Train Loss: 1.528 | Train PPL:   4.607
# 	 Val. Loss: 5.333 |  Val. PPL: 207.013
# Epoch: 194 | Time: 0m 51s
# 	Train Loss: 1.529 | Train PPL:   4.615
# 	 Val. Loss: 5.381 |  Val. PPL: 217.297
# Epoch: 195 | Time: 0m 50s
# 	Train Loss: 1.525 | Train PPL:   4.593
# 	 Val. Loss: 5.384 |  Val. PPL: 217.959
# Epoch: 196 | Time: 0m 50s
# 	Train Loss: 1.522 | Train PPL:   4.582
# 	 Val. Loss: 5.375 |  Val. PPL: 215.882
# Epoch: 197 | Time: 0m 50s
# 	Train Loss: 1.526 | Train PPL:   4.599
# 	 Val. Loss: 5.346 |  Val. PPL: 209.732
# Epoch: 198 | Time: 0m 50s
# 	Train Loss: 1.517 | Train PPL:   4.556
# 	 Val. Loss: 5.343 |  Val. PPL: 209.070
# Epoch: 199 | Time: 0m 50s
# 	Train Loss: 1.519 | Train PPL:   4.570
# 	 Val. Loss: 5.318 |  Val. PPL: 203.910
# Epoch: 200 | Time: 0m 50s
# 	Train Loss: 1.520 | Train PPL:   4.570
# 	 Val. Loss: 5.308 |  Val. PPL: 202.023
# Epoch: 201 | Time: 0m 50s
# 	Train Loss: 1.516 | Train PPL:   4.553
# 	 Val. Loss: 5.363 |  Val. PPL: 213.264
# Epoch: 202 | Time: 0m 50s
# 	Train Loss: 1.519 | Train PPL:   4.565
# 	 Val. Loss: 5.362 |  Val. PPL: 213.110
# Epoch: 203 | Time: 0m 50s
# 	Train Loss: 1.517 | Train PPL:   4.558
# 	 Val. Loss: 5.384 |  Val. PPL: 217.823
# Epoch: 204 | Time: 0m 50s
# 	Train Loss: 1.516 | Train PPL:   4.554
# 	 Val. Loss: 5.393 |  Val. PPL: 219.882
# Epoch: 205 | Time: 0m 50s
# 	Train Loss: 1.510 | Train PPL:   4.525
# 	 Val. Loss: 5.342 |  Val. PPL: 208.985
# Epoch: 206 | Time: 0m 50s
# 	Train Loss: 1.514 | Train PPL:   4.543
# 	 Val. Loss: 5.392 |  Val. PPL: 219.539
# Epoch: 207 | Time: 0m 50s
# 	Train Loss: 1.510 | Train PPL:   4.527
# 	 Val. Loss: 5.323 |  Val. PPL: 205.020
# Epoch: 208 | Time: 0m 50s
# 	Train Loss: 1.506 | Train PPL:   4.510
# 	 Val. Loss: 5.347 |  Val. PPL: 209.915
# Epoch: 209 | Time: 0m 50s
# 	Train Loss: 1.505 | Train PPL:   4.503
# 	 Val. Loss: 5.359 |  Val. PPL: 212.438
# Epoch: 210 | Time: 0m 50s
# 	Train Loss: 1.506 | Train PPL:   4.510
# 	 Val. Loss: 5.403 |  Val. PPL: 221.985
# Epoch: 211 | Time: 0m 50s
# 	Train Loss: 1.505 | Train PPL:   4.506
# 	 Val. Loss: 5.300 |  Val. PPL: 200.364
# Epoch: 212 | Time: 0m 50s
# 	Train Loss: 1.504 | Train PPL:   4.499
# 	 Val. Loss: 5.354 |  Val. PPL: 211.480
# Epoch: 213 | Time: 0m 50s
# 	Train Loss: 1.501 | Train PPL:   4.486
# 	 Val. Loss: 5.370 |  Val. PPL: 214.809
# Epoch: 214 | Time: 0m 50s
# 	Train Loss: 1.499 | Train PPL:   4.478
# 	 Val. Loss: 5.421 |  Val. PPL: 226.015
# Epoch: 215 | Time: 0m 50s
# 	Train Loss: 1.497 | Train PPL:   4.470
# 	 Val. Loss: 5.380 |  Val. PPL: 217.115
# Epoch: 216 | Time: 0m 50s
# 	Train Loss: 1.499 | Train PPL:   4.478
# 	 Val. Loss: 5.375 |  Val. PPL: 216.038
# Epoch: 217 | Time: 0m 50s
# 	Train Loss: 1.499 | Train PPL:   4.477
# 	 Val. Loss: 5.340 |  Val. PPL: 208.509
# Epoch: 218 | Time: 0m 50s
# 	Train Loss: 1.495 | Train PPL:   4.457
# 	 Val. Loss: 5.360 |  Val. PPL: 212.687
# Epoch: 219 | Time: 0m 50s
# 	Train Loss: 1.495 | Train PPL:   4.458
# 	 Val. Loss: 5.434 |  Val. PPL: 228.959
# Epoch: 220 | Time: 0m 50s
# 	Train Loss: 1.493 | Train PPL:   4.452
# 	 Val. Loss: 5.400 |  Val. PPL: 221.433
# Epoch: 221 | Time: 0m 50s
# 	Train Loss: 1.492 | Train PPL:   4.444
# 	 Val. Loss: 5.388 |  Val. PPL: 218.673
# Epoch: 222 | Time: 0m 50s
# 	Train Loss: 1.491 | Train PPL:   4.443
# 	 Val. Loss: 5.399 |  Val. PPL: 221.126
# Epoch: 223 | Time: 0m 50s
# 	Train Loss: 1.491 | Train PPL:   4.440
# 	 Val. Loss: 5.370 |  Val. PPL: 214.804
# Epoch: 224 | Time: 0m 50s
# 	Train Loss: 1.490 | Train PPL:   4.437
# 	 Val. Loss: 5.377 |  Val. PPL: 216.297
# Epoch: 225 | Time: 0m 50s
# 	Train Loss: 1.486 | Train PPL:   4.420
# 	 Val. Loss: 5.400 |  Val. PPL: 221.337
# Epoch: 226 | Time: 0m 50s
# 	Train Loss: 1.486 | Train PPL:   4.420
# 	 Val. Loss: 5.412 |  Val. PPL: 224.169
# Epoch: 227 | Time: 0m 50s
# 	Train Loss: 1.486 | Train PPL:   4.419
# 	 Val. Loss: 5.385 |  Val. PPL: 218.150
# Epoch: 228 | Time: 0m 50s
# 	Train Loss: 1.480 | Train PPL:   4.394
# 	 Val. Loss: 5.431 |  Val. PPL: 228.305
# Epoch: 229 | Time: 0m 50s
# 	Train Loss: 1.482 | Train PPL:   4.402
# 	 Val. Loss: 5.427 |  Val. PPL: 227.354
# Epoch: 230 | Time: 0m 50s
# 	Train Loss: 1.482 | Train PPL:   4.401
# 	 Val. Loss: 5.453 |  Val. PPL: 233.409
# Epoch: 231 | Time: 0m 50s
# 	Train Loss: 1.482 | Train PPL:   4.402
# 	 Val. Loss: 5.376 |  Val. PPL: 216.164
# Epoch: 232 | Time: 0m 50s
# 	Train Loss: 1.480 | Train PPL:   4.391
# 	 Val. Loss: 5.435 |  Val. PPL: 229.273
# Epoch: 233 | Time: 0m 50s
# 	Train Loss: 1.481 | Train PPL:   4.396
# 	 Val. Loss: 5.387 |  Val. PPL: 218.479
# Epoch: 234 | Time: 0m 50s
# 	Train Loss: 1.475 | Train PPL:   4.373
# 	 Val. Loss: 5.472 |  Val. PPL: 237.834
# Epoch: 235 | Time: 0m 50s
# 	Train Loss: 1.476 | Train PPL:   4.377
# 	 Val. Loss: 5.418 |  Val. PPL: 225.335
# Epoch: 236 | Time: 0m 50s
# 	Train Loss: 1.473 | Train PPL:   4.364
# 	 Val. Loss: 5.447 |  Val. PPL: 231.967
# Epoch: 237 | Time: 0m 50s
# 	Train Loss: 1.474 | Train PPL:   4.365
# 	 Val. Loss: 5.457 |  Val. PPL: 234.414
# Epoch: 238 | Time: 0m 50s
# 	Train Loss: 1.471 | Train PPL:   4.352
# 	 Val. Loss: 5.475 |  Val. PPL: 238.681
# Epoch: 239 | Time: 0m 50s
# 	Train Loss: 1.469 | Train PPL:   4.345
# 	 Val. Loss: 5.462 |  Val. PPL: 235.582
# Epoch: 240 | Time: 0m 50s
# 	Train Loss: 1.471 | Train PPL:   4.353
# 	 Val. Loss: 5.516 |  Val. PPL: 248.753
# Epoch: 241 | Time: 0m 50s
# 	Train Loss: 1.469 | Train PPL:   4.344
# 	 Val. Loss: 5.416 |  Val. PPL: 224.922
# Epoch: 242 | Time: 0m 50s
# 	Train Loss: 1.472 | Train PPL:   4.359
# 	 Val. Loss: 5.444 |  Val. PPL: 231.429
# Epoch: 243 | Time: 0m 50s
# 	Train Loss: 1.467 | Train PPL:   4.336
# 	 Val. Loss: 5.471 |  Val. PPL: 237.730
# Epoch: 244 | Time: 0m 50s
# 	Train Loss: 1.468 | Train PPL:   4.341
# 	 Val. Loss: 5.511 |  Val. PPL: 247.291
# Epoch: 245 | Time: 0m 50s
# 	Train Loss: 1.464 | Train PPL:   4.324
# 	 Val. Loss: 5.424 |  Val. PPL: 226.879
# Epoch: 246 | Time: 0m 50s
# 	Train Loss: 1.466 | Train PPL:   4.331
# 	 Val. Loss: 5.468 |  Val. PPL: 237.021
# Epoch: 247 | Time: 0m 50s
# 	Train Loss: 1.464 | Train PPL:   4.325
# 	 Val. Loss: 5.417 |  Val. PPL: 225.272
# Epoch: 248 | Time: 0m 50s
# 	Train Loss: 1.464 | Train PPL:   4.321
# 	 Val. Loss: 5.452 |  Val. PPL: 233.183
# Epoch: 249 | Time: 0m 50s
# 	Train Loss: 1.461 | Train PPL:   4.309
# 	 Val. Loss: 5.371 |  Val. PPL: 215.024
# Epoch: 250 | Time: 0m 50s
# 	Train Loss: 1.463 | Train PPL:   4.321
# 	 Val. Loss: 5.473 |  Val. PPL: 238.227
# Epoch: 251 | Time: 0m 50s
# 	Train Loss: 1.459 | Train PPL:   4.301
# 	 Val. Loss: 5.458 |  Val. PPL: 234.516
# Epoch: 252 | Time: 0m 50s
# 	Train Loss: 1.457 | Train PPL:   4.293
# 	 Val. Loss: 5.472 |  Val. PPL: 237.964
# Epoch: 253 | Time: 0m 50s
# 	Train Loss: 1.455 | Train PPL:   4.284
# 	 Val. Loss: 5.512 |  Val. PPL: 247.739
# Epoch: 254 | Time: 0m 50s
# 	Train Loss: 1.455 | Train PPL:   4.286
# 	 Val. Loss: 5.470 |  Val. PPL: 237.443
# Epoch: 255 | Time: 0m 51s
# 	Train Loss: 1.452 | Train PPL:   4.274
# 	 Val. Loss: 5.474 |  Val. PPL: 238.441
# Epoch: 256 | Time: 0m 51s
# 	Train Loss: 1.449 | Train PPL:   4.259
# 	 Val. Loss: 5.453 |  Val. PPL: 233.506
# Epoch: 257 | Time: 0m 51s
# 	Train Loss: 1.453 | Train PPL:   4.276
# 	 Val. Loss: 5.428 |  Val. PPL: 227.763
# Epoch: 258 | Time: 0m 51s
# 	Train Loss: 1.454 | Train PPL:   4.281
# 	 Val. Loss: 5.414 |  Val. PPL: 224.560
# Epoch: 259 | Time: 0m 50s
# 	Train Loss: 1.450 | Train PPL:   4.262
# 	 Val. Loss: 5.411 |  Val. PPL: 223.766
# Epoch: 260 | Time: 0m 50s
# 	Train Loss: 1.453 | Train PPL:   4.275
# 	 Val. Loss: 5.453 |  Val. PPL: 233.537
# Epoch: 261 | Time: 0m 50s
# 	Train Loss: 1.454 | Train PPL:   4.279
# 	 Val. Loss: 5.469 |  Val. PPL: 237.151
# Epoch: 262 | Time: 0m 50s
# 	Train Loss: 1.447 | Train PPL:   4.252
# 	 Val. Loss: 5.421 |  Val. PPL: 226.141
# Epoch: 263 | Time: 0m 50s
# 	Train Loss: 1.446 | Train PPL:   4.247
# 	 Val. Loss: 5.458 |  Val. PPL: 234.618
# Epoch: 264 | Time: 0m 50s
# 	Train Loss: 1.443 | Train PPL:   4.233
# 	 Val. Loss: 5.487 |  Val. PPL: 241.484
# Epoch: 265 | Time: 0m 50s
# 	Train Loss: 1.442 | Train PPL:   4.230
# 	 Val. Loss: 5.494 |  Val. PPL: 243.222
# Epoch: 266 | Time: 0m 50s
# 	Train Loss: 1.444 | Train PPL:   4.239
# 	 Val. Loss: 5.538 |  Val. PPL: 254.187
# Epoch: 267 | Time: 0m 50s
# 	Train Loss: 1.442 | Train PPL:   4.227
# 	 Val. Loss: 5.470 |  Val. PPL: 237.492
# Epoch: 268 | Time: 0m 50s
# 	Train Loss: 1.441 | Train PPL:   4.224
# 	 Val. Loss: 5.459 |  Val. PPL: 234.886
# Epoch: 269 | Time: 0m 50s
# 	Train Loss: 1.442 | Train PPL:   4.228
# 	 Val. Loss: 5.437 |  Val. PPL: 229.858
# Epoch: 270 | Time: 0m 50s
# 	Train Loss: 1.443 | Train PPL:   4.233
# 	 Val. Loss: 5.509 |  Val. PPL: 247.022
# Epoch: 271 | Time: 0m 50s
# 	Train Loss: 1.439 | Train PPL:   4.218
# 	 Val. Loss: 5.476 |  Val. PPL: 238.841
# Epoch: 272 | Time: 0m 50s
# 	Train Loss: 1.440 | Train PPL:   4.220
# 	 Val. Loss: 5.507 |  Val. PPL: 246.410
# Epoch: 273 | Time: 0m 50s
# 	Train Loss: 1.440 | Train PPL:   4.222
# 	 Val. Loss: 5.458 |  Val. PPL: 234.615
# Epoch: 274 | Time: 0m 50s
# 	Train Loss: 1.435 | Train PPL:   4.201
# 	 Val. Loss: 5.424 |  Val. PPL: 226.746
# Epoch: 275 | Time: 0m 50s
# 	Train Loss: 1.436 | Train PPL:   4.206
# 	 Val. Loss: 5.489 |  Val. PPL: 242.066
# Epoch: 276 | Time: 0m 50s
# 	Train Loss: 1.435 | Train PPL:   4.199
# 	 Val. Loss: 5.503 |  Val. PPL: 245.395
# Epoch: 277 | Time: 0m 50s
# 	Train Loss: 1.436 | Train PPL:   4.202
# 	 Val. Loss: 5.463 |  Val. PPL: 235.692
# Epoch: 278 | Time: 0m 50s
# 	Train Loss: 1.435 | Train PPL:   4.198
# 	 Val. Loss: 5.472 |  Val. PPL: 238.001
# Epoch: 279 | Time: 0m 50s
# 	Train Loss: 1.432 | Train PPL:   4.188
# 	 Val. Loss: 5.445 |  Val. PPL: 231.647
# Epoch: 280 | Time: 0m 50s
# 	Train Loss: 1.432 | Train PPL:   4.187
# 	 Val. Loss: 5.532 |  Val. PPL: 252.558
# Epoch: 281 | Time: 0m 50s
# 	Train Loss: 1.432 | Train PPL:   4.186
# 	 Val. Loss: 5.454 |  Val. PPL: 233.742
# Epoch: 282 | Time: 0m 50s
# 	Train Loss: 1.431 | Train PPL:   4.183
# 	 Val. Loss: 5.500 |  Val. PPL: 244.733
# Epoch: 283 | Time: 0m 50s
# 	Train Loss: 1.433 | Train PPL:   4.192
# 	 Val. Loss: 5.443 |  Val. PPL: 231.098
# Epoch: 284 | Time: 0m 50s
# 	Train Loss: 1.425 | Train PPL:   4.158
# 	 Val. Loss: 5.505 |  Val. PPL: 245.954
# Epoch: 285 | Time: 0m 50s
# 	Train Loss: 1.426 | Train PPL:   4.160
# 	 Val. Loss: 5.475 |  Val. PPL: 238.720
# Epoch: 286 | Time: 0m 50s
# 	Train Loss: 1.427 | Train PPL:   4.166
# 	 Val. Loss: 5.538 |  Val. PPL: 254.094
# Epoch: 287 | Time: 0m 50s
# 	Train Loss: 1.425 | Train PPL:   4.157
# 	 Val. Loss: 5.522 |  Val. PPL: 250.171
# Epoch: 288 | Time: 0m 50s
# 	Train Loss: 1.422 | Train PPL:   4.145
# 	 Val. Loss: 5.506 |  Val. PPL: 246.201
# Epoch: 289 | Time: 0m 50s
# 	Train Loss: 1.426 | Train PPL:   4.163
# 	 Val. Loss: 5.521 |  Val. PPL: 249.880
# Epoch: 290 | Time: 0m 50s
# 	Train Loss: 1.425 | Train PPL:   4.159
# 	 Val. Loss: 5.484 |  Val. PPL: 240.883
# Epoch: 291 | Time: 0m 50s
# 	Train Loss: 1.419 | Train PPL:   4.134
# 	 Val. Loss: 5.495 |  Val. PPL: 243.363
# Epoch: 292 | Time: 0m 50s
# 	Train Loss: 1.423 | Train PPL:   4.149
# 	 Val. Loss: 5.526 |  Val. PPL: 251.217
# Epoch: 293 | Time: 0m 50s
# 	Train Loss: 1.423 | Train PPL:   4.150
# 	 Val. Loss: 5.487 |  Val. PPL: 241.577
# Epoch: 294 | Time: 0m 50s
# 	Train Loss: 1.420 | Train PPL:   4.135
# 	 Val. Loss: 5.524 |  Val. PPL: 250.620
# Epoch: 295 | Time: 0m 50s
# 	Train Loss: 1.418 | Train PPL:   4.128
# 	 Val. Loss: 5.570 |  Val. PPL: 262.422
# Epoch: 296 | Time: 0m 50s
# 	Train Loss: 1.414 | Train PPL:   4.112
# 	 Val. Loss: 5.525 |  Val. PPL: 250.778
# Epoch: 297 | Time: 0m 50s
# 	Train Loss: 1.415 | Train PPL:   4.115
# 	 Val. Loss: 5.548 |  Val. PPL: 256.783
# Epoch: 298 | Time: 0m 50s
# 	Train Loss: 1.415 | Train PPL:   4.118
# 	 Val. Loss: 5.510 |  Val. PPL: 247.061
# Epoch: 299 | Time: 0m 50s
# 	Train Loss: 1.412 | Train PPL:   4.106
# 	 Val. Loss: 5.559 |  Val. PPL: 259.645
# Epoch: 300 | Time: 0m 50s
# 	Train Loss: 1.415 | Train PPL:   4.115
# 	 Val. Loss: 5.542 |  Val. PPL: 255.199
# Epoch: 301 | Time: 0m 50s
# 	Train Loss: 1.413 | Train PPL:   4.110
# 	 Val. Loss: 5.508 |  Val. PPL: 246.595
# Epoch: 302 | Time: 0m 50s
# 	Train Loss: 1.410 | Train PPL:   4.095
# 	 Val. Loss: 5.592 |  Val. PPL: 268.340
# Epoch: 303 | Time: 0m 50s
# 	Train Loss: 1.413 | Train PPL:   4.106
# 	 Val. Loss: 5.559 |  Val. PPL: 259.664
# Epoch: 304 | Time: 0m 50s
# 	Train Loss: 1.406 | Train PPL:   4.079
# 	 Val. Loss: 5.577 |  Val. PPL: 264.214
# Epoch: 305 | Time: 0m 50s
# 	Train Loss: 1.407 | Train PPL:   4.082
# 	 Val. Loss: 5.539 |  Val. PPL: 254.302
# Epoch: 306 | Time: 0m 50s
# 	Train Loss: 1.406 | Train PPL:   4.080
# 	 Val. Loss: 5.553 |  Val. PPL: 257.890
# Epoch: 307 | Time: 0m 50s
# 	Train Loss: 1.408 | Train PPL:   4.090
# 	 Val. Loss: 5.555 |  Val. PPL: 258.481
# Epoch: 308 | Time: 0m 50s
# 	Train Loss: 1.404 | Train PPL:   4.071
# 	 Val. Loss: 5.554 |  Val. PPL: 258.389
# Epoch: 309 | Time: 0m 50s
# 	Train Loss: 1.404 | Train PPL:   4.071
# 	 Val. Loss: 5.526 |  Val. PPL: 251.019
# Epoch: 310 | Time: 0m 50s
# 	Train Loss: 1.406 | Train PPL:   4.079
# 	 Val. Loss: 5.596 |  Val. PPL: 269.339
# Epoch: 311 | Time: 0m 50s
# 	Train Loss: 1.402 | Train PPL:   4.064
# 	 Val. Loss: 5.592 |  Val. PPL: 268.193
# Epoch: 312 | Time: 0m 50s
# 	Train Loss: 1.400 | Train PPL:   4.055
# 	 Val. Loss: 5.573 |  Val. PPL: 263.199
# Epoch: 313 | Time: 0m 50s
# 	Train Loss: 1.397 | Train PPL:   4.041
# 	 Val. Loss: 5.583 |  Val. PPL: 265.848
# Epoch: 314 | Time: 0m 50s
# 	Train Loss: 1.402 | Train PPL:   4.063
# 	 Val. Loss: 5.565 |  Val. PPL: 261.231
# Epoch: 315 | Time: 0m 50s
# 	Train Loss: 1.400 | Train PPL:   4.057
# 	 Val. Loss: 5.537 |  Val. PPL: 253.885
# Epoch: 316 | Time: 0m 50s
# 	Train Loss: 1.395 | Train PPL:   4.034
# 	 Val. Loss: 5.530 |  Val. PPL: 252.036
# Epoch: 317 | Time: 0m 50s
# 	Train Loss: 1.400 | Train PPL:   4.057
# 	 Val. Loss: 5.608 |  Val. PPL: 272.706
# Epoch: 318 | Time: 0m 50s
# 	Train Loss: 1.403 | Train PPL:   4.066
# 	 Val. Loss: 5.543 |  Val. PPL: 255.448
# Epoch: 319 | Time: 0m 50s
# 	Train Loss: 1.397 | Train PPL:   4.042
# 	 Val. Loss: 5.544 |  Val. PPL: 255.711
# Epoch: 320 | Time: 0m 50s
# 	Train Loss: 1.398 | Train PPL:   4.047
# 	 Val. Loss: 5.507 |  Val. PPL: 246.459
# Epoch: 321 | Time: 0m 50s
# 	Train Loss: 1.394 | Train PPL:   4.031
# 	 Val. Loss: 5.582 |  Val. PPL: 265.641
# Epoch: 322 | Time: 0m 50s
# 	Train Loss: 1.393 | Train PPL:   4.025
# 	 Val. Loss: 5.592 |  Val. PPL: 268.141
# Epoch: 323 | Time: 0m 50s
# 	Train Loss: 1.395 | Train PPL:   4.036
# 	 Val. Loss: 5.546 |  Val. PPL: 256.099
# Epoch: 324 | Time: 0m 50s
# 	Train Loss: 1.393 | Train PPL:   4.028
# 	 Val. Loss: 5.550 |  Val. PPL: 257.268
# Epoch: 325 | Time: 0m 50s
# 	Train Loss: 1.390 | Train PPL:   4.016
# 	 Val. Loss: 5.607 |  Val. PPL: 272.256
# Epoch: 326 | Time: 0m 50s
# 	Train Loss: 1.392 | Train PPL:   4.024
# 	 Val. Loss: 5.627 |  Val. PPL: 277.814
# Epoch: 327 | Time: 0m 50s
# 	Train Loss: 1.388 | Train PPL:   4.008
# 	 Val. Loss: 5.587 |  Val. PPL: 267.056
# Epoch: 328 | Time: 0m 50s
# 	Train Loss: 1.391 | Train PPL:   4.018
# 	 Val. Loss: 5.559 |  Val. PPL: 259.691
# Epoch: 329 | Time: 0m 50s
# 	Train Loss: 1.389 | Train PPL:   4.009
# 	 Val. Loss: 5.600 |  Val. PPL: 270.549
# Epoch: 330 | Time: 0m 50s
# 	Train Loss: 1.389 | Train PPL:   4.010
# 	 Val. Loss: 5.630 |  Val. PPL: 278.684

# %%
def evaluate(sentence, trg_sentence_field, model, device,max_length=10):
  model.eval()

  tokens = [token.lower() for token in sentence]

  tokens = [trg_sentence_field.init_token] + tokens + [trg_sentence_field.eos_token]
  src_indexes = [trg_sentence_field.vocab.stoi[token] for token in tokens]
  src_tensor = torch.LongTensor(src_indexes).unsqueeze(0).to(device)
  src_mask = model.make_src_mask(src_tensor)

  with torch.no_grad():
      enc_src = model.encoder(src_tensor, src_mask)

  trg_indexes = [trg_sentence_field.vocab.stoi[trg_sentence_field.init_token]]#Initializing with an init token for target input

  for i in range(max_length):

        trg_tensor = torch.LongTensor(trg_indexes).unsqueeze(0).to(device)

        trg_mask = model.make_trg_mask(trg_tensor)
        
        with torch.no_grad():
            output, attention = model.decoder(trg_tensor, enc_src, trg_mask, src_mask)
        
        pred_token = output.argmax(2)[:,-1].item()
        
        trg_indexes.append(pred_token)

        if pred_token == trg_sentence_field.vocab.stoi[trg_sentence_field.eos_token]:
            break
    
  trg_tokens = [trg_sentence_field.vocab.itos[i] for i in trg_indexes]
  return trg_tokens[1:]

# %%
def evaluateInput( trg_sentence_field,model, device):
    input_sentence = ''
    while(True):
        try:
            # Get input sentence from the user
            input_sentence = input('> ')
            # Check if it is quit case
            if input_sentence == 'q' or input_sentence == 'quit': break
            # Normalize sentence
            input_sentence = normalizeString(input_sentence)
            # Evaluate sentence
            output_words = evaluate(input_sentence,trg_sentence_field, model, device,max_length=10)
            # Format and print response sentence
            output_words[:] = [x for x in output_words if not (x == '<eos>' or x == '<pad>' or x == '<unk>')]
            print('Bot:', ' '.join(output_words))

        except KeyError:
            print("Error: Encountered unknown word.")

# %%
evaluateInput(sentence,model, device)
